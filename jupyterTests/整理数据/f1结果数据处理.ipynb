# %%
import sys
sys.path.append('D:\PyCharmProjects\VFPUMC02')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from utils.ExpResultUtils import *

# %%
df = pd.read_csv('./f1_result.csv', sep='\t', usecols=lambda col: col not in ['method', 'row_no'])
data = df.values

# %%
write_data_to_file_general(
    data,
    'data_f1.txt',
    sort_blocks=True,
    block_size=4,
    block_order=[0,3,1,2],
    sort_rows_flag=True
)

# %%
df2 = pd.read_csv('./match_f1.csv',sep='\t')

# %%
group_and_restructure(df2)
# Out:
# adamatch	0.428571429	0.384615385	0.428571429	0.428571429	0.428571429	0.272727273	0.384615385	0.272727273	0.272727273
# fixmatch	0.428571429	0.384615385	0.2	0.428571429	0.428571429	0.272727273	0.272727273	0.272727273	0.272727273
# flexmatch	0.428571429	0.384615385	0.428571429	0.428571429	0.2	0.272727273	0.384615385	0.272727273	0.272727273
# fullysupervised	0.428571429	0.272727273	0.2	0.428571429	0.2	0.384615385	0.384615385	0.384615385	0.272727273
# meanteacher	0.2	0.384615385	0.428571429	0.2	0.428571429	0.384615385	0.384615385	0.272727273	0.272727273
# mixmatch	0.2	0.384615385	0.2	0.2	0.428571429	0.272727273	0.272727273	0.384615385	0.384615385
# pimodel	0.428571429	0.384615385	0.2	0.2	0.428571429	0.272727273	0.384615385	0.384615385	0.272727273
# pseudolabel	0.2	0.384615385	0.428571429	0.2	0.2	0.384615385	0.384615385	0.272727273	0.384615385
# remixmatch	0.428571429	0.384615385	0.2	0.428571429	0.428571429	0.384615385	0.384615385	0.384615385	0.272727273
# ...
