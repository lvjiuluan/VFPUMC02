# %%
import sys
sys.path.append('D:\PyCharmProjects\VFPUMC02')
# %load_ext autoreload
# %autoreload 2

# %%
from consts.Constants import DATASETS_PATH
import pandas as pd
import os

# %%
result = pd.read_csv(os.path.join(DATASETS_PATH,'SklearnSemiMethodBank.csv'),header=[0,1],index_col=0)

# %%
result
# Out:
# Method Label Spreading                               Label Propagation  \
# Metric        Accuracy    Recall       AUC        F1          Accuracy
# bank          0.941719  0.589011  0.958417  0.690722          0.917678
# bank          0.940755  0.611714  0.950479  0.698020          0.919874
# bank          0.940110  0.613160  0.948955  0.696223          0.913564
# bank          0.937299  0.598413  0.945325  0.686495          0.913323
# bank          0.933330  0.574361  0.933179  0.666343          0.907740
# bank          0.931976  0.582095  0.935050  0.656448          0.903488
# bank          0.927543  0.551166  0.930662  0.629150          0.906628
# bank          0.917724  0.503864  0.914033  0.582473          0.900698
# bank          0.907794  0.479403  0.898931  0.537983          0.894656
# census        0.722052  0.133172  0.574590  0.195556          0.704545
# census        0.726658  0.138942  0.571723  0.196751          0.712070
# ...
