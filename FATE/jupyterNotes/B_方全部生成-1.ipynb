# %%
import sys
sys.path.append('D:\PyCharmProjects\VFPUMC02')
sys.path.append(r'C:\Users\Administrator\PycharmProjects\VFPUMC02')
sys.path.append(r'/root/VFPUMC02')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datasets.DataSet import BankDataset
from utils.DataProcessUtils import split_labeled_unlabeled, vertical_split_array
from utils.DataProcessUtils import find_rounds_math
from utils.FateUtils import evaluate_model
from classfiers.VF_TwoStep import VF_TwoStep
from vf4lr.VF_LR import VF_LR
from classfiers.VF_LinearRegression import VF_LinearRegression
from enums.ModelType import ModelType

# %%
bankDataset = BankDataset()
X, y = bankDataset.get_data()
X, y_C, y_R = X[:,:-1], y, X[:,-1]
XA, XB = vertical_split_array(X,random_state=24,first_col_rate=0.5)
# Out:
# 2025-01-21 21:08:32,980 - INFO - 正在加载数据集 bank.csv
# 2025-01-21 21:08:33,206 - INFO - 数据集 bank.csv 加载完成，数据集形状为 (41188, 64)

# %%
labeled, unlabeled = split_labeled_unlabeled(XA,XB,y_C,y_R,random_state=24,k=0.2)
# Out:
# 总样本数: 41188
# 输入数组 0 的形状: (41188, 31)
# 输入数组 1 的形状: (41188, 31)
# 输入数组 2 的形状: (41188,)
# 输入数组 3 的形状: (41188,)
# 选择 8237 个样本作为有标签数据，剩余样本作为无标签数据
# 输入数组 0 的有标签数据形状: (8237, 31)
# 输入数组 0 的无标签数据形状: (32951, 31)
# 输入数组 1 的有标签数据形状: (8237, 31)
# 输入数组 1 的无标签数据形状: (32951, 31)
# 输入数组 2 的有标签数据形状: (8237,)
# 输入数组 2 的无标签数据形状: (32951,)
# 输入数组 3 的有标签数据形状: (8237,)
# 输入数组 3 的无标签数据形状: (32951,)

# %%
# 解包 labeled（有标签数据）
XA_L, XB_L, y_C_L, y_R_L = labeled
# 解包 unlabeled（无标签数据
XA_U, XB_U, y_C_U, y_R_U = unlabeled

# %%
vf_clf = VF_LR(
    learning_rate=0.2,
    epoch_num=10,
    batch_size=128
)
vf_reg = VF_LinearRegression(
    config={
    'batch_size': 32,
    'lr': 0.01,
    'lambda': 0.1,
    'n_iters':10
    }
)
# Out:
# 2025-01-21 21:22:40,986 - ConsoleLogger - INFO - VF_LinearRegression 模型初始化完成。
# 2025-01-21 21:22:40,986 - INFO - VF_LinearRegression 模型初始化完成。
# 2025-01-21 21:22:40,992 - ConsoleLogger - INFO - 模型配置: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}
# 2025-01-21 21:22:40,992 - INFO - 模型配置: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}

# %%
vf_two_step = VF_TwoStep(
    clf=vf_clf,
    reg=vf_reg,
    k=0.1,
    max_iter=100
)
# Out:
# 2025-01-21 21:24:59,682 - INFO - VF_TwoStep 类已成功初始化: max_iter=100, k=0.10, min_confidence=0.00, convergence_threshold=0, clf=VF_LR, reg=VF_LinearRegression

# %%
vf_two_step.fit?
# Out:
# Signature: vf_two_step.fit(XA_L, XB_L, y_L, XA_U, XB_U)
# Docstring:
# 训练 TwoStep 模型。
#
# 参数:
# - XA_L (numpy ndarray): 有标签数据的特征矩阵 A，形状为 (n_labeled_samples, n_features_A)。
# - XB_L (numpy ndarray): 有标签数据的特征矩阵 B，形状为 (n_labeled_samples, n_features_B)。
# - y_L (numpy ndarray): 有标签数据的标签向量，形状为 (n_labeled_samples, )。
# - XA_U (numpy ndarray): 无标签数据的特征矩阵 A，形状为 (n_unlabeled_samples, n_features_A)。
# - XB_U (numpy ndarray): 无标签数据的特征矩阵 B，形状为 (n_unlabeled_samples, n_features_B)。
#
# 返回:
# - self: 训练后的模型实例。
# File:      ~/VFPUMC02/classfiers/VF_TwoStep.py
# Type:      method

# %%
vf_two_step.fit(
    XA_L=XA_L,
    XB_L=XB_L,
    y_L=y_C_L,
    XA_U=XA_U,
    XB_U=XB_U
)
# Out:
# 2025-01-21 21:26:06,931 - INFO - 有标签数据 (L): 8237 样本
# 2025-01-21 21:26:06,932 - INFO - 无标签数据 (U): 32951 样本
# 2025-01-21 21:26:06,933 - INFO - 任务类型判定结果: classification
# 2025-01-21 21:26:06,933 - INFO - 这是一个分类任务。
# 2025-01-21 21:26:06,934 - INFO - 分类任务中的类别: [0 1]
# 2025-01-21 21:26:06,935 - INFO - [INIT] 初始化 self.pred, 未标注数据数量=32951
# 2025-01-21 21:26:06,935 - INFO - [INIT] 最大迭代次数 max_iter=100, 每轮选取比例 k=0.10
# 2025-01-21 21:26:06,935 - INFO - ===== [Epoch 1/100] 迭代开始 =====
# 2025-01-21 21:26:06,936 - INFO - [INFO] 当前 Labeled 样本数量: 8237, Unlabeled 样本数量: 32951
# 2025-01-21 21:26:06,936 - INFO - [STEP 1] 开始训练分类器 (基于 8237 个 Labeled 样本)...
# 2025-01-21 21:26:06,937 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (8237, 31), 客户端B训练数据形状: (8237, 31), 标签大小: 8237
# 2025-01-21 21:26:06,937 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (8237, 31), 客户端B训练数据形状: (8237, 31), 标签大小: 8237
# 2025-01-21 21:26:06,938 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:06,938 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:06,939 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:06,939 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:06,939 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:06,939 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:06,940 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:06,940 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:06,941 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (32951, 31), 客户端B测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,941 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (32951, 31), 客户端B测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,941 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:06,941 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:06,942 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:06,942 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:06,944 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:06,944 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:06,945 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (8237, 31), 测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,945 - INFO - Client 0 初始化完成，训练数据形状: (8237, 31), 测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,946 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (8237, 31), 测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,946 - INFO - Client 1 初始化完成，训练数据形状: (8237, 31), 测试数据形状: (32951, 31)
# 2025-01-21 21:26:06,947 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:06,947 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:06,947 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:06,947 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:06,948 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:06,948 - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:07,046 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:07,046 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:07,047 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:07,047 - INFO - 开始第 2/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:07,149 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:07,149 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:07,150 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:07,150 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:07,251 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:07,251 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:07,252 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:07,252 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:07,350 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:07,350 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:07,351 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:07,351 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:07,449 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:07,449 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:07,450 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:07,450 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:07,548 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:07,548 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:07,549 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:07,549 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:07,647 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:07,647 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:07,648 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:07,648 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:07,745 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:07,745 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:07,745 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:07,745 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:07,842 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:07,842 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:07,843 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:07,843 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:07,940 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:07,940 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:07,941 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:07,941 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:07,941 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:07,941 - INFO - 联邦训练完成。
# 2025-01-21 21:26:08,358 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:08,358 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:08,359 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:08,359 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:08,360 - ConsoleLogger - INFO - 返回预测概率，形状: (32951, 2)
# 2025-01-21 21:26:08,360 - INFO - 返回预测概率，形状: (32951, 2)
# 2025-01-21 21:26:08,362 - INFO - [STEP 2] 预测概率计算完成，耗时 1.42 秒。
# 2025-01-21 21:26:08,363 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:08,364 - INFO - [STEP 3] 本轮选中高置信度样本数量: 3295, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:08,364 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:08,364 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (32951, 31), 客户端B测试数据形状: (32951, 31)
# 2025-01-21 21:26:08,364 - INFO - 开始进行预测，客户端A测试数据形状: (32951, 31), 客户端B测试数据形状: (32951, 31)
# 2025-01-21 21:26:08,365 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:08,365 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:08,366 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:08,369 - INFO - [STEP 5] 合并后 Labeled 样本数=11532
# 2025-01-21 21:26:08,379 - INFO - [STEP 5] 剩余 Unlabeled 样本数=29656
# 2025-01-21 21:26:08,380 - INFO - ===== [Epoch 1/100] 迭代结束，耗时 1.44 秒 =====
# 2025-01-21 21:26:08,380 - INFO - ===== [Epoch 2/100] 迭代开始 =====
# 2025-01-21 21:26:08,380 - INFO - [INFO] 当前 Labeled 样本数量: 11532, Unlabeled 样本数量: 29656
# 2025-01-21 21:26:08,381 - INFO - [STEP 1] 开始训练分类器 (基于 11532 个 Labeled 样本)...
# 2025-01-21 21:26:08,382 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (11532, 31), 客户端B训练数据形状: (11532, 31), 标签大小: 11532
# 2025-01-21 21:26:08,382 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (11532, 31), 客户端B训练数据形状: (11532, 31), 标签大小: 11532
# 2025-01-21 21:26:08,383 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:08,383 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:08,383 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:08,383 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:08,384 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:08,384 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:08,385 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:08,385 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:08,385 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (29656, 31), 客户端B测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,385 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (29656, 31), 客户端B测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,386 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:08,386 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:08,387 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:08,387 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:08,389 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:08,389 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:08,389 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (11532, 31), 测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,389 - INFO - Client 0 初始化完成，训练数据形状: (11532, 31), 测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,390 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (11532, 31), 测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,390 - INFO - Client 1 初始化完成，训练数据形状: (11532, 31), 测试数据形状: (29656, 31)
# 2025-01-21 21:26:08,391 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:08,391 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:08,391 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:08,391 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:08,392 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:08,392 - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:08,527 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:08,527 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:08,528 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:08,528 - INFO - 开始第 2/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:08,665 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:08,665 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:08,666 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:08,666 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:08,801 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:08,801 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:08,802 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:08,802 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:08,937 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:08,937 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:08,938 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:08,938 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:09,072 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:09,072 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:09,073 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:09,073 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:09,206 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:09,206 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:09,207 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:09,207 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:09,341 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:09,341 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:09,341 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:09,341 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:09,478 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:09,478 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:09,479 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:09,479 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:09,613 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:09,613 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:09,614 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:09,614 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:09,747 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:09,747 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:09,748 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:09,748 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:09,748 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:09,748 - INFO - 联邦训练完成。
# 2025-01-21 21:26:10,083 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:10,083 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:10,084 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:10,084 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:10,085 - ConsoleLogger - INFO - 返回预测概率，形状: (29656, 2)
# 2025-01-21 21:26:10,085 - INFO - 返回预测概率，形状: (29656, 2)
# 2025-01-21 21:26:10,087 - INFO - [STEP 2] 预测概率计算完成，耗时 1.70 秒。
# 2025-01-21 21:26:10,088 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:10,089 - INFO - [STEP 3] 本轮选中高置信度样本数量: 2965, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:10,089 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:10,089 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (29656, 31), 客户端B测试数据形状: (29656, 31)
# 2025-01-21 21:26:10,089 - INFO - 开始进行预测，客户端A测试数据形状: (29656, 31), 客户端B测试数据形状: (29656, 31)
# 2025-01-21 21:26:10,090 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:10,090 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:10,091 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:10,097 - INFO - [STEP 5] 合并后 Labeled 样本数=14497
# 2025-01-21 21:26:10,105 - INFO - [STEP 5] 剩余 Unlabeled 样本数=26691
# 2025-01-21 21:26:10,106 - INFO - ===== [Epoch 2/100] 迭代结束，耗时 1.73 秒 =====
# 2025-01-21 21:26:10,106 - INFO - ===== [Epoch 3/100] 迭代开始 =====
# 2025-01-21 21:26:10,107 - INFO - [INFO] 当前 Labeled 样本数量: 14497, Unlabeled 样本数量: 26691
# 2025-01-21 21:26:10,107 - INFO - [STEP 1] 开始训练分类器 (基于 14497 个 Labeled 样本)...
# 2025-01-21 21:26:10,108 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (14497, 31), 客户端B训练数据形状: (14497, 31), 标签大小: 14497
# 2025-01-21 21:26:10,108 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (14497, 31), 客户端B训练数据形状: (14497, 31), 标签大小: 14497
# 2025-01-21 21:26:10,109 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:10,109 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:10,109 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:10,109 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:10,110 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:10,110 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:10,111 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:10,111 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:10,111 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (26691, 31), 客户端B测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,111 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (26691, 31), 客户端B测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,112 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:10,112 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:10,113 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:10,113 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:10,115 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:10,115 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:10,116 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (14497, 31), 测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,116 - INFO - Client 0 初始化完成，训练数据形状: (14497, 31), 测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,117 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (14497, 31), 测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,117 - INFO - Client 1 初始化完成，训练数据形状: (14497, 31), 测试数据形状: (26691, 31)
# 2025-01-21 21:26:10,117 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:10,117 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:10,118 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:10,118 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:10,119 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:10,119 - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:10,287 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:10,287 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:10,288 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:10,288 - INFO - 开始第 2/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:10,457 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:10,457 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:10,458 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:10,458 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:10,624 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:10,624 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:10,625 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:10,625 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:10,792 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:10,792 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:10,793 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:10,793 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:10,961 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:10,961 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:10,962 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:10,962 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:11,135 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:11,135 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:11,136 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:11,136 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:11,304 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:11,304 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:11,305 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:11,305 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:11,473 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:11,473 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:11,474 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:11,474 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:11,645 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:11,645 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:11,646 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:11,646 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:11,817 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:11,817 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:11,818 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:11,818 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:11,818 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:11,818 - INFO - 联邦训练完成。
# 2025-01-21 21:26:12,125 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:12,125 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:12,126 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:12,126 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:12,127 - ConsoleLogger - INFO - 返回预测概率，形状: (26691, 2)
# 2025-01-21 21:26:12,127 - INFO - 返回预测概率，形状: (26691, 2)
# 2025-01-21 21:26:12,129 - INFO - [STEP 2] 预测概率计算完成，耗时 2.02 秒。
# 2025-01-21 21:26:12,130 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:12,131 - INFO - [STEP 3] 本轮选中高置信度样本数量: 2669, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:12,131 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:12,131 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (26691, 31), 客户端B测试数据形状: (26691, 31)
# 2025-01-21 21:26:12,131 - INFO - 开始进行预测，客户端A测试数据形状: (26691, 31), 客户端B测试数据形状: (26691, 31)
# 2025-01-21 21:26:12,132 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:12,132 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:12,133 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:12,138 - INFO - [STEP 5] 合并后 Labeled 样本数=17166
# 2025-01-21 21:26:12,145 - INFO - [STEP 5] 剩余 Unlabeled 样本数=24022
# 2025-01-21 21:26:12,145 - INFO - ===== [Epoch 3/100] 迭代结束，耗时 2.04 秒 =====
# 2025-01-21 21:26:12,145 - INFO - ===== [Epoch 4/100] 迭代开始 =====
# 2025-01-21 21:26:12,146 - INFO - [INFO] 当前 Labeled 样本数量: 17166, Unlabeled 样本数量: 24022
# 2025-01-21 21:26:12,146 - INFO - [STEP 1] 开始训练分类器 (基于 17166 个 Labeled 样本)...
# 2025-01-21 21:26:12,147 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (17166, 31), 客户端B训练数据形状: (17166, 31), 标签大小: 17166
# 2025-01-21 21:26:12,147 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (17166, 31), 客户端B训练数据形状: (17166, 31), 标签大小: 17166
# 2025-01-21 21:26:12,148 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:12,148 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:12,149 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:12,149 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:12,149 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:12,149 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:12,150 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:12,151 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:12,151 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (24022, 31), 客户端B测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,151 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (24022, 31), 客户端B测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,152 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:12,152 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:12,152 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:12,152 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:12,154 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:12,154 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:12,155 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (17166, 31), 测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,155 - INFO - Client 0 初始化完成，训练数据形状: (17166, 31), 测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,156 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (17166, 31), 测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,156 - INFO - Client 1 初始化完成，训练数据形状: (17166, 31), 测试数据形状: (24022, 31)
# 2025-01-21 21:26:12,157 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:12,157 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:12,158 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:12,158 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:12,158 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:12,158 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:12,361 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:12,361 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:12,362 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:12,362 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:12,559 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:12,559 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:12,560 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:12,560 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:12,758 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:12,758 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:12,759 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:12,759 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:12,965 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:12,965 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:12,966 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:12,966 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:13,169 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:13,169 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:13,171 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:13,171 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:13,371 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:13,371 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:13,372 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:13,372 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:13,571 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:13,571 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:13,572 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:13,572 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:13,771 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:13,771 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:13,772 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:13,772 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:13,982 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:13,982 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:13,983 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:13,983 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:14,184 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:14,184 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:14,187 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:14,187 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:14,187 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:14,187 - INFO - 联邦训练完成。
# 2025-01-21 21:26:14,448 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:14,448 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:14,450 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:14,450 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:14,451 - ConsoleLogger - INFO - 返回预测概率，形状: (24022, 2)
# 2025-01-21 21:26:14,451 - INFO - 返回预测概率，形状: (24022, 2)
# 2025-01-21 21:26:14,453 - INFO - [STEP 2] 预测概率计算完成，耗时 2.30 秒。
# 2025-01-21 21:26:14,453 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:14,454 - INFO - [STEP 3] 本轮选中高置信度样本数量: 2402, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:14,455 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:14,455 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (24022, 31), 客户端B测试数据形状: (24022, 31)
# 2025-01-21 21:26:14,455 - INFO - 开始进行预测，客户端A测试数据形状: (24022, 31), 客户端B测试数据形状: (24022, 31)
# 2025-01-21 21:26:14,456 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:14,456 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:14,457 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:14,461 - INFO - [STEP 5] 合并后 Labeled 样本数=19568
# 2025-01-21 21:26:14,465 - INFO - [STEP 5] 剩余 Unlabeled 样本数=21620
# 2025-01-21 21:26:14,465 - INFO - ===== [Epoch 4/100] 迭代结束，耗时 2.32 秒 =====
# 2025-01-21 21:26:14,465 - INFO - ===== [Epoch 5/100] 迭代开始 =====
# 2025-01-21 21:26:14,466 - INFO - [INFO] 当前 Labeled 样本数量: 19568, Unlabeled 样本数量: 21620
# 2025-01-21 21:26:14,466 - INFO - [STEP 1] 开始训练分类器 (基于 19568 个 Labeled 样本)...
# 2025-01-21 21:26:14,467 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (19568, 31), 客户端B训练数据形状: (19568, 31), 标签大小: 19568
# 2025-01-21 21:26:14,467 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (19568, 31), 客户端B训练数据形状: (19568, 31), 标签大小: 19568
# 2025-01-21 21:26:14,468 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:14,468 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:14,469 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:14,469 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:14,470 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:14,470 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:14,470 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:14,471 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:14,471 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (21620, 31), 客户端B测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,471 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (21620, 31), 客户端B测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,472 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:14,472 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:14,472 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:14,472 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:14,474 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:14,474 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:14,475 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (19568, 31), 测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,475 - INFO - Client 0 初始化完成，训练数据形状: (19568, 31), 测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,476 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (19568, 31), 测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,476 - INFO - Client 1 初始化完成，训练数据形状: (19568, 31), 测试数据形状: (21620, 31)
# 2025-01-21 21:26:14,477 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:14,477 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:14,477 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:14,477 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:14,478 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:14,478 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:14,706 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:14,706 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:14,707 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:14,707 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:14,931 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:14,931 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:14,932 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:14,932 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:15,162 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:15,162 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:15,163 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:15,163 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:15,387 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:15,387 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:15,388 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:15,388 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:15,613 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:15,613 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:15,614 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:15,614 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:15,839 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:15,839 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:15,840 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:15,840 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:16,069 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:16,069 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:16,070 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:16,070 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:16,307 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:16,307 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:16,308 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:16,308 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:16,539 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:16,539 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:16,540 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:16,540 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:16,770 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:16,770 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:16,771 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:16,771 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:16,771 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:16,771 - INFO - 联邦训练完成。
# 2025-01-21 21:26:16,996 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:16,996 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:16,997 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:16,997 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:16,998 - ConsoleLogger - INFO - 返回预测概率，形状: (21620, 2)
# 2025-01-21 21:26:16,998 - INFO - 返回预测概率，形状: (21620, 2)
# 2025-01-21 21:26:16,999 - INFO - [STEP 2] 预测概率计算完成，耗时 2.53 秒。
# 2025-01-21 21:26:17,000 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:17,001 - INFO - [STEP 3] 本轮选中高置信度样本数量: 2162, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:17,001 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:17,002 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (21620, 31), 客户端B测试数据形状: (21620, 31)
# 2025-01-21 21:26:17,002 - INFO - 开始进行预测，客户端A测试数据形状: (21620, 31), 客户端B测试数据形状: (21620, 31)
# 2025-01-21 21:26:17,002 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:17,002 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:17,003 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:17,007 - INFO - [STEP 5] 合并后 Labeled 样本数=21730
# 2025-01-21 21:26:17,010 - INFO - [STEP 5] 剩余 Unlabeled 样本数=19458
# 2025-01-21 21:26:17,010 - INFO - ===== [Epoch 5/100] 迭代结束，耗时 2.55 秒 =====
# 2025-01-21 21:26:17,011 - INFO - ===== [Epoch 6/100] 迭代开始 =====
# 2025-01-21 21:26:17,011 - INFO - [INFO] 当前 Labeled 样本数量: 21730, Unlabeled 样本数量: 19458
# 2025-01-21 21:26:17,011 - INFO - [STEP 1] 开始训练分类器 (基于 21730 个 Labeled 样本)...
# 2025-01-21 21:26:17,012 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (21730, 31), 客户端B训练数据形状: (21730, 31), 标签大小: 21730
# 2025-01-21 21:26:17,012 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (21730, 31), 客户端B训练数据形状: (21730, 31), 标签大小: 21730
# 2025-01-21 21:26:17,013 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:17,013 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:17,015 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:17,015 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:17,016 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:17,016 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:17,016 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:17,017 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:17,017 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (19458, 31), 客户端B测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,017 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (19458, 31), 客户端B测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,018 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:17,018 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:17,019 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:17,019 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:17,020 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:17,020 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:17,021 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (21730, 31), 测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,021 - INFO - Client 0 初始化完成，训练数据形状: (21730, 31), 测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,022 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (21730, 31), 测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,022 - INFO - Client 1 初始化完成，训练数据形状: (21730, 31), 测试数据形状: (19458, 31)
# 2025-01-21 21:26:17,022 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:17,022 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:17,023 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:17,023 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:17,024 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:17,024 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:17,283 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:17,283 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:17,284 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:17,284 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:17,537 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:17,537 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:17,538 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:17,538 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:17,787 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:17,787 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:17,788 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:17,788 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:18,038 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:18,038 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:18,039 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:18,039 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:18,298 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:18,298 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:18,299 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:18,299 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:18,552 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:18,552 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:18,553 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:18,553 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:18,804 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:18,804 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:18,805 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:18,805 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:19,055 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:19,055 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:19,056 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:19,056 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:19,314 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:19,314 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:19,316 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:19,316 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:19,572 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:19,572 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:19,573 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:19,573 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:19,574 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:19,574 - INFO - 联邦训练完成。
# 2025-01-21 21:26:19,784 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:19,784 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:19,785 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:19,785 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:19,786 - ConsoleLogger - INFO - 返回预测概率，形状: (19458, 2)
# 2025-01-21 21:26:19,786 - INFO - 返回预测概率，形状: (19458, 2)
# 2025-01-21 21:26:19,788 - INFO - [STEP 2] 预测概率计算完成，耗时 2.77 秒。
# 2025-01-21 21:26:19,789 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:19,789 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1945, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:19,790 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:19,790 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (19458, 31), 客户端B测试数据形状: (19458, 31)
# 2025-01-21 21:26:19,790 - INFO - 开始进行预测，客户端A测试数据形状: (19458, 31), 客户端B测试数据形状: (19458, 31)
# 2025-01-21 21:26:19,791 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:19,791 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:19,792 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:19,795 - INFO - [STEP 5] 合并后 Labeled 样本数=23675
# 2025-01-21 21:26:19,798 - INFO - [STEP 5] 剩余 Unlabeled 样本数=17513
# 2025-01-21 21:26:19,798 - INFO - ===== [Epoch 6/100] 迭代结束，耗时 2.79 秒 =====
# 2025-01-21 21:26:19,799 - INFO - ===== [Epoch 7/100] 迭代开始 =====
# 2025-01-21 21:26:19,799 - INFO - [INFO] 当前 Labeled 样本数量: 23675, Unlabeled 样本数量: 17513
# 2025-01-21 21:26:19,799 - INFO - [STEP 1] 开始训练分类器 (基于 23675 个 Labeled 样本)...
# 2025-01-21 21:26:19,801 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (23675, 31), 客户端B训练数据形状: (23675, 31), 标签大小: 23675
# 2025-01-21 21:26:19,801 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (23675, 31), 客户端B训练数据形状: (23675, 31), 标签大小: 23675
# 2025-01-21 21:26:19,801 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:19,801 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:19,802 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:19,802 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:19,803 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:19,803 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:19,803 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:19,804 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:19,804 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (17513, 31), 客户端B测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,804 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (17513, 31), 客户端B测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,805 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:19,805 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:19,805 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:19,805 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:19,807 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:19,807 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:19,808 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (23675, 31), 测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,808 - INFO - Client 0 初始化完成，训练数据形状: (23675, 31), 测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,809 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (23675, 31), 测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,809 - INFO - Client 1 初始化完成，训练数据形状: (23675, 31), 测试数据形状: (17513, 31)
# 2025-01-21 21:26:19,810 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:19,810 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:19,810 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:19,810 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:19,811 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:19,811 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:20,093 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:20,093 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:20,094 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:20,094 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:20,367 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:20,367 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:20,369 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:20,369 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:20,645 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:20,645 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:20,646 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:20,646 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:20,932 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:20,932 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:20,933 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:20,933 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:21,204 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:21,204 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:21,205 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:21,205 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:21,477 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:21,477 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:21,478 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:21,478 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:21,750 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:21,750 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:21,751 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:21,751 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:22,022 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:22,022 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:22,023 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:22,023 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:22,296 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:22,296 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:22,297 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:22,297 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:22,570 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:22,570 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:22,570 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:22,570 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:22,571 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:22,571 - INFO - 联邦训练完成。
# 2025-01-21 21:26:22,753 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:22,753 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:22,753 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:22,753 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:22,754 - ConsoleLogger - INFO - 返回预测概率，形状: (17513, 2)
# 2025-01-21 21:26:22,754 - INFO - 返回预测概率，形状: (17513, 2)
# 2025-01-21 21:26:22,756 - INFO - [STEP 2] 预测概率计算完成，耗时 2.95 秒。
# 2025-01-21 21:26:22,757 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:22,757 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1751, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:22,758 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:22,758 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (17513, 31), 客户端B测试数据形状: (17513, 31)
# 2025-01-21 21:26:22,758 - INFO - 开始进行预测，客户端A测试数据形状: (17513, 31), 客户端B测试数据形状: (17513, 31)
# 2025-01-21 21:26:22,759 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:22,759 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:22,760 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:22,763 - INFO - [STEP 5] 合并后 Labeled 样本数=25426
# 2025-01-21 21:26:22,765 - INFO - [STEP 5] 剩余 Unlabeled 样本数=15762
# 2025-01-21 21:26:22,766 - INFO - ===== [Epoch 7/100] 迭代结束，耗时 2.97 秒 =====
# 2025-01-21 21:26:22,766 - INFO - ===== [Epoch 8/100] 迭代开始 =====
# 2025-01-21 21:26:22,767 - INFO - [INFO] 当前 Labeled 样本数量: 25426, Unlabeled 样本数量: 15762
# 2025-01-21 21:26:22,767 - INFO - [STEP 1] 开始训练分类器 (基于 25426 个 Labeled 样本)...
# 2025-01-21 21:26:22,768 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (25426, 31), 客户端B训练数据形状: (25426, 31), 标签大小: 25426
# 2025-01-21 21:26:22,768 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (25426, 31), 客户端B训练数据形状: (25426, 31), 标签大小: 25426
# 2025-01-21 21:26:22,769 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:22,769 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:26:22,769 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:22,769 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:26:22,770 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:22,770 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:26:22,771 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:26:22,771 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:26:22,772 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (15762, 31), 客户端B测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,772 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (15762, 31), 客户端B测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,772 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:22,772 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:26:22,773 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:22,773 - INFO - 初始化 Server 对象。
# 2025-01-21 21:26:22,775 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:22,775 - INFO - 初始化 Client 对象。
# 2025-01-21 21:26:22,776 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (25426, 31), 测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,776 - INFO - Client 0 初始化完成，训练数据形状: (25426, 31), 测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,777 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (25426, 31), 测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,777 - INFO - Client 1 初始化完成，训练数据形状: (25426, 31), 测试数据形状: (15762, 31)
# 2025-01-21 21:26:22,778 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:22,778 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:26:22,778 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:22,778 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:26:22,779 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:26:22,779 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:26:23,081 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:23,081 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:26:23,082 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:23,082 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:26:23,376 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:23,376 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:26:23,377 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:23,377 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:26:23,671 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:23,671 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:26:23,671 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:23,671 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:26:23,966 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:23,966 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:26:23,967 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:23,967 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:26:24,260 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:24,260 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:26:24,261 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:24,261 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:26:24,557 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:24,557 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:26:24,558 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:24,558 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:26:24,858 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:24,858 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:26:24,860 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:24,860 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:26:25,157 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:25,157 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:26:25,158 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:25,158 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:26:25,458 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:25,458 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:26:25,459 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:25,459 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:26:25,752 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:25,752 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:26:25,753 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:25,753 - INFO - 所有轮次训练完成。
# 2025-01-21 21:26:25,754 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:26:25,754 - INFO - 联邦训练完成。
# 2025-01-21 21:26:25,917 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:26:25,917 - INFO - 获取最终预测结果。
# 2025-01-21 21:26:25,918 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:25,918 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:26:25,919 - ConsoleLogger - INFO - 返回预测概率，形状: (15762, 2)
# 2025-01-21 21:26:25,919 - INFO - 返回预测概率，形状: (15762, 2)
# 2025-01-21 21:26:25,921 - INFO - [STEP 2] 预测概率计算完成，耗时 3.15 秒。
# 2025-01-21 21:26:25,921 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:26:25,922 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1576, 占未标注样本总数的 10.00%
# 2025-01-21 21:26:25,923 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:26:25,923 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (15762, 31), 客户端B测试数据形状: (15762, 31)
# 2025-01-21 21:26:25,923 - INFO - 开始进行预测，客户端A测试数据形状: (15762, 31), 客户端B测试数据形状: (15762, 31)
# 2025-01-21 21:26:25,924 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:25,924 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:26:25,925 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:26:25,931 - INFO - [STEP 5] 合并后 Labeled 样本数=27002
# 2025-01-21 21:26:25,935 - INFO - [STEP 5] 剩余 Unlabeled 样本数=14186
# 2025-01-21 21:26:25,935 - INFO - ===== [Epoch 8/100] 迭代结束，耗时 3.17 秒 =====
# 2025-01-21 21:26:25,935 - INFO - ===== [Epoch 9/100] 迭代开始 =====
# 2025-01-21 21:26:25,936 - INFO - [INFO] 当前 Labeled 样本数量: 27002, Unlabeled 样本数量: 14186
# 2025-01-21 21:26:25,936 - INFO - [STEP 1] 开始训练分类器 (基于 27002 个 Labeled 样本)...
# 2025-01-21 21:26:25,937 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (27002, 31), 客户端B训练数据形状: (27002, 31), 标签大小: 27002
# 2025-01-21 21:26:25,937 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (27002, 31), 客户端B训练数据形状: (27002, 31), 标签大小: 27002
# ...
# 2025-01-21 21:32:45,804 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (41185, 31), 测试数据形状: (3, 31)
# 2025-01-21 21:32:45,804 - INFO - Client 1 初始化完成，训练数据形状: (41185, 31), 测试数据形状: (3, 31)
# 2025-01-21 21:32:45,805 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:45,805 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:45,806 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:45,806 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:45,807 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:32:45,807 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:32:46,288 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:46,288 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:46,289 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:46,289 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:46,774 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:46,774 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:46,775 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:46,775 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:47,254 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:47,254 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:47,255 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:47,255 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:47,734 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:47,734 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:47,735 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:47,735 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:48,221 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:48,221 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:48,222 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:48,222 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:48,703 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:48,703 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:48,704 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:48,704 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:49,200 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:49,200 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:49,201 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:49,201 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:49,684 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:49,684 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:49,685 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:49,685 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:50,164 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:50,164 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:50,165 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:32:50,165 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:32:50,645 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:32:50,645 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:32:50,646 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:32:50,646 - INFO - 所有轮次训练完成。
# 2025-01-21 21:32:50,647 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:32:50,647 - INFO - 联邦训练完成。
# 2025-01-21 21:32:50,648 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:32:50,648 - INFO - 获取最终预测结果。
# 2025-01-21 21:32:50,649 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:32:50,649 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:32:50,650 - ConsoleLogger - INFO - 返回预测概率，形状: (3, 2)
# 2025-01-21 21:32:50,650 - INFO - 返回预测概率，形状: (3, 2)
# 2025-01-21 21:32:50,650 - INFO - [STEP 2] 预测概率计算完成，耗时 4.85 秒。
# 2025-01-21 21:32:50,651 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:32:50,651 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1, 占未标注样本总数的 33.33%
# 2025-01-21 21:32:50,652 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:32:50,652 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (3, 31), 客户端B测试数据形状: (3, 31)
# 2025-01-21 21:32:50,652 - INFO - 开始进行预测，客户端A测试数据形状: (3, 31), 客户端B测试数据形状: (3, 31)
# 2025-01-21 21:32:50,653 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:32:50,653 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:32:50,655 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:32:50,669 - INFO - [STEP 5] 合并后 Labeled 样本数=41186
# 2025-01-21 21:32:50,669 - INFO - [STEP 5] 剩余 Unlabeled 样本数=2
# 2025-01-21 21:32:50,670 - INFO - ===== [Epoch 90/100] 迭代结束，耗时 4.88 秒 =====
# 2025-01-21 21:32:50,670 - INFO - ===== [Epoch 91/100] 迭代开始 =====
# 2025-01-21 21:32:50,670 - INFO - [INFO] 当前 Labeled 样本数量: 41186, Unlabeled 样本数量: 2
# 2025-01-21 21:32:50,671 - INFO - [STEP 1] 开始训练分类器 (基于 41186 个 Labeled 样本)...
# 2025-01-21 21:32:50,672 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (41186, 31), 客户端B训练数据形状: (41186, 31), 标签大小: 41186
# 2025-01-21 21:32:50,672 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (41186, 31), 客户端B训练数据形状: (41186, 31), 标签大小: 41186
# 2025-01-21 21:32:50,672 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:32:50,672 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:32:50,673 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:32:50,673 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:32:50,674 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:32:50,674 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:32:50,674 - INFO - [STEP 1] 分类器训练完成，耗时 0.00 秒。
# 2025-01-21 21:32:50,675 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:32:50,675 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (2, 31), 客户端B测试数据形状: (2, 31)
# 2025-01-21 21:32:50,675 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (2, 31), 客户端B测试数据形状: (2, 31)
# 2025-01-21 21:32:50,676 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:32:50,676 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:32:50,677 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:32:50,677 - INFO - 初始化 Server 对象。
# 2025-01-21 21:32:50,677 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:32:50,677 - INFO - 初始化 Client 对象。
# 2025-01-21 21:32:50,679 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (41186, 31), 测试数据形状: (2, 31)
# 2025-01-21 21:32:50,679 - INFO - Client 0 初始化完成，训练数据形状: (41186, 31), 测试数据形状: (2, 31)
# 2025-01-21 21:32:50,680 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (41186, 31), 测试数据形状: (2, 31)
# 2025-01-21 21:32:50,680 - INFO - Client 1 初始化完成，训练数据形状: (41186, 31), 测试数据形状: (2, 31)
# 2025-01-21 21:32:50,681 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:50,681 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:50,682 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:50,682 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:50,682 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:32:50,682 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:32:51,173 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:51,173 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:51,174 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:51,174 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:51,654 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:51,654 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:51,655 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:51,655 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:52,129 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:52,129 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:52,130 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:52,130 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:52,604 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:52,604 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:52,605 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:52,605 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:53,083 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:53,083 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:53,084 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:53,084 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:53,567 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:53,567 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:53,568 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:53,568 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:54,044 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:54,044 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:54,045 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:54,045 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:54,520 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:54,520 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:54,521 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:54,521 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:54,999 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:54,999 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:55,001 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:32:55,001 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:32:55,484 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:32:55,484 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:32:55,486 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:32:55,486 - INFO - 所有轮次训练完成。
# 2025-01-21 21:32:55,487 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:32:55,487 - INFO - 联邦训练完成。
# 2025-01-21 21:32:55,489 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:32:55,489 - INFO - 获取最终预测结果。
# 2025-01-21 21:32:55,490 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:32:55,490 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:32:55,491 - ConsoleLogger - INFO - 返回预测概率，形状: (2, 2)
# 2025-01-21 21:32:55,491 - INFO - 返回预测概率，形状: (2, 2)
# 2025-01-21 21:32:55,492 - INFO - [STEP 2] 预测概率计算完成，耗时 4.82 秒。
# 2025-01-21 21:32:55,493 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:32:55,493 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1, 占未标注样本总数的 50.00%
# 2025-01-21 21:32:55,493 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:32:55,494 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (2, 31), 客户端B测试数据形状: (2, 31)
# 2025-01-21 21:32:55,494 - INFO - 开始进行预测，客户端A测试数据形状: (2, 31), 客户端B测试数据形状: (2, 31)
# 2025-01-21 21:32:55,494 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:32:55,494 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:32:55,495 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:32:55,502 - INFO - [STEP 5] 合并后 Labeled 样本数=41187
# 2025-01-21 21:32:55,502 - INFO - [STEP 5] 剩余 Unlabeled 样本数=1
# 2025-01-21 21:32:55,503 - INFO - ===== [Epoch 91/100] 迭代结束，耗时 4.83 秒 =====
# 2025-01-21 21:32:55,503 - INFO - ===== [Epoch 92/100] 迭代开始 =====
# 2025-01-21 21:32:55,504 - INFO - [INFO] 当前 Labeled 样本数量: 41187, Unlabeled 样本数量: 1
# 2025-01-21 21:32:55,505 - INFO - [STEP 1] 开始训练分类器 (基于 41187 个 Labeled 样本)...
# 2025-01-21 21:32:55,508 - ConsoleLogger - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (41187, 31), 客户端B训练数据形状: (41187, 31), 标签大小: 41187
# 2025-01-21 21:32:55,508 - INFO - 开始训练垂直联邦逻辑回归模型，客户端A训练数据形状: (41187, 31), 客户端B训练数据形状: (41187, 31), 标签大小: 41187
# 2025-01-21 21:32:55,509 - ConsoleLogger - INFO - 检测到的类别数量: 2
# 2025-01-21 21:32:55,509 - INFO - 检测到的类别数量: 2
# 2025-01-21 21:32:55,511 - ConsoleLogger - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:32:55,511 - INFO - 模型配置：学习率=0.2, 训练轮数=10, 批大小=128, 客户端数=2
# 2025-01-21 21:32:55,512 - ConsoleLogger - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:32:55,512 - INFO - 完成模型初始化，等待调用 predict 或 predict_proba 进行训练和预测。
# 2025-01-21 21:32:55,513 - INFO - [STEP 1] 分类器训练完成，耗时 0.01 秒。
# 2025-01-21 21:32:55,513 - INFO - [STEP 2] 对 Unlabeled 数据进行预测概率计算...
# 2025-01-21 21:32:55,514 - ConsoleLogger - INFO - 开始进行预测概率计算，客户端A测试数据形状: (1, 31), 客户端B测试数据形状: (1, 31)
# 2025-01-21 21:32:55,514 - INFO - 开始进行预测概率计算，客户端A测试数据形状: (1, 31), 客户端B测试数据形状: (1, 31)
# 2025-01-21 21:32:55,515 - ConsoleLogger - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:32:55,515 - INFO - 模型尚未训练，开始执行联邦训练流程。
# 2025-01-21 21:32:55,515 - ConsoleLogger - INFO - 初始化 Server 对象。
# 2025-01-21 21:32:55,515 - INFO - 初始化 Server 对象。
# 2025-01-21 21:32:55,516 - ConsoleLogger - INFO - 初始化 Client 对象。
# 2025-01-21 21:32:55,516 - INFO - 初始化 Client 对象。
# 2025-01-21 21:32:55,518 - ConsoleLogger - INFO - Client 0 初始化完成，训练数据形状: (41187, 31), 测试数据形状: (1, 31)
# 2025-01-21 21:32:55,518 - INFO - Client 0 初始化完成，训练数据形状: (41187, 31), 测试数据形状: (1, 31)
# 2025-01-21 21:32:55,519 - ConsoleLogger - INFO - Client 1 初始化完成，训练数据形状: (41187, 31), 测试数据形状: (1, 31)
# 2025-01-21 21:32:55,519 - INFO - Client 1 初始化完成，训练数据形状: (41187, 31), 测试数据形状: (1, 31)
# 2025-01-21 21:32:55,520 - ConsoleLogger - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:55,520 - INFO - 所有客户端挂载至 Server 完成，开始进行联邦训练。
# 2025-01-21 21:32:55,521 - ConsoleLogger - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:55,521 - INFO - 开始 VFL LR 训练，共 10 轮。
# 2025-01-21 21:32:55,522 - ConsoleLogger - INFO - 开始第 1/10 轮训练...
# 2025-01-21 21:32:55,522 - INFO - 开始第 1/10 轮训练...
# 检测到二分类任务 (Binary Classification)
# 输入标签 y 的唯一值个数: 2, 唯一值: [0 1]
# 2025-01-21 21:32:56,010 - ConsoleLogger - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:56,010 - INFO - 第 1 轮训练完成。
# 2025-01-21 21:32:56,011 - ConsoleLogger - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:56,011 - INFO - 开始第 2/10 轮训练...
# 2025-01-21 21:32:56,487 - ConsoleLogger - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:56,487 - INFO - 第 2 轮训练完成。
# 2025-01-21 21:32:56,488 - ConsoleLogger - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:56,488 - INFO - 开始第 3/10 轮训练...
# 2025-01-21 21:32:56,969 - ConsoleLogger - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:56,969 - INFO - 第 3 轮训练完成。
# 2025-01-21 21:32:56,970 - ConsoleLogger - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:56,970 - INFO - 开始第 4/10 轮训练...
# 2025-01-21 21:32:57,444 - ConsoleLogger - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:57,444 - INFO - 第 4 轮训练完成。
# 2025-01-21 21:32:57,445 - ConsoleLogger - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:57,445 - INFO - 开始第 5/10 轮训练...
# 2025-01-21 21:32:57,927 - ConsoleLogger - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:57,927 - INFO - 第 5 轮训练完成。
# 2025-01-21 21:32:57,928 - ConsoleLogger - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:57,928 - INFO - 开始第 6/10 轮训练...
# 2025-01-21 21:32:58,403 - ConsoleLogger - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:58,403 - INFO - 第 6 轮训练完成。
# 2025-01-21 21:32:58,404 - ConsoleLogger - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:58,404 - INFO - 开始第 7/10 轮训练...
# 2025-01-21 21:32:58,881 - ConsoleLogger - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:58,881 - INFO - 第 7 轮训练完成。
# 2025-01-21 21:32:58,882 - ConsoleLogger - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:58,882 - INFO - 开始第 8/10 轮训练...
# 2025-01-21 21:32:59,356 - ConsoleLogger - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:59,356 - INFO - 第 8 轮训练完成。
# 2025-01-21 21:32:59,357 - ConsoleLogger - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:59,357 - INFO - 开始第 9/10 轮训练...
# 2025-01-21 21:32:59,834 - ConsoleLogger - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:59,834 - INFO - 第 9 轮训练完成。
# 2025-01-21 21:32:59,835 - ConsoleLogger - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:32:59,835 - INFO - 开始第 10/10 轮训练...
# 2025-01-21 21:33:00,314 - ConsoleLogger - INFO - 第 10 轮训练完成。
# 2025-01-21 21:33:00,314 - INFO - 第 10 轮训练完成。
# 2025-01-21 21:33:00,315 - ConsoleLogger - INFO - 所有轮次训练完成。
# 2025-01-21 21:33:00,315 - INFO - 所有轮次训练完成。
# 2025-01-21 21:33:00,315 - ConsoleLogger - INFO - 联邦训练完成。
# 2025-01-21 21:33:00,315 - INFO - 联邦训练完成。
# 2025-01-21 21:33:00,316 - ConsoleLogger - INFO - 获取最终预测结果。
# 2025-01-21 21:33:00,316 - INFO - 获取最终预测结果。
# 2025-01-21 21:33:00,317 - ConsoleLogger - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:33:00,317 - INFO - 模型训练完成并已缓存预测结果。
# 2025-01-21 21:33:00,318 - ConsoleLogger - INFO - 返回预测概率，形状: (1, 2)
# 2025-01-21 21:33:00,318 - INFO - 返回预测概率，形状: (1, 2)
# 2025-01-21 21:33:00,318 - INFO - [STEP 2] 预测概率计算完成，耗时 4.80 秒。
# 2025-01-21 21:33:00,319 - INFO - [STEP 3] 按置信度选取前 10.00% 的未标注样本 (min_confidence=0.00)...
# 2025-01-21 21:33:00,319 - INFO - [STEP 3] 本轮选中高置信度样本数量: 1, 占未标注样本总数的 100.00%
# 2025-01-21 21:33:00,319 - INFO - [STEP 4] 获取高置信度样本的预测标签。
# 2025-01-21 21:33:00,320 - ConsoleLogger - INFO - 开始进行预测，客户端A测试数据形状: (1, 31), 客户端B测试数据形状: (1, 31)
# 2025-01-21 21:33:00,320 - INFO - 开始进行预测，客户端A测试数据形状: (1, 31), 客户端B测试数据形状: (1, 31)
# 2025-01-21 21:33:00,320 - ConsoleLogger - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:33:00,320 - INFO - 模型已训练，直接返回之前的预测结果。
# 2025-01-21 21:33:00,323 - INFO - [STEP 5] 合并高置信度样本至 Labeled 集...
# 2025-01-21 21:33:00,337 - INFO - [STEP 5] 合并后 Labeled 样本数=41188
# 2025-01-21 21:33:00,337 - INFO - [STEP 5] 剩余 Unlabeled 样本数=0
# 2025-01-21 21:33:00,338 - INFO - [INFO] Unlabeled 样本已全部处理完，提前结束迭代。
# 2025-01-21 21:33:00,338 - INFO - [DONE] 自训练流程结束，共进行了 92 轮迭代，耗时 413.40 秒。
# 2025-01-21 21:33:00,338 - INFO - [DONE] 目前尚有 0 个未标注样本未获得最终预测。
# 2025-01-21 21:33:00,339 - INFO - [DONE] 所有未标注样本的预测任务完成！(self.pred 已更新)
# 2025-01-21 21:33:00,340 - INFO - VF_TwoStep 模型训练完成。

# %%
y_C_pred = vf_two_step.get_unlabeled_predict(ModelType.CLASSIFICATION)

# %%
evaluate_model(y_C_U,y_C_pred)
# Out:
# ========== Classification Metrics ==========
# Accuracy         : 0.1117
# Precision (macro): 0.0559
# Recall (macro)   : 0.5000
# F1 (macro)       : 0.1005
#
# Confusion Matrix:
# [[    0 29269]
#  [    0  3682]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     29269
#            1       0.11      1.00      0.20      3682
#
#     accuracy                           0.11     32951
#    macro avg       0.06      0.50      0.10     32951
# weighted avg       0.01      0.11      0.02     32951

# %%
vf_two_step.fit(
    XA_L=XA_L,
    XB_L=XB_L,
    y_L=y_R_L,
    XA_U=XA_U,
    XB_U=XB_U
)

# %%
y_R_pred = vf_two_step.get_unlabeled_predict(ModelType.REGRESSION)

# %%
evaluate_model(y_R_U, y_R_pred, model_type=ModelType.REGRESSION)
# Out:
# ========== Regression Metrics ==========
# MSE               : 0.8393
# RMSE              : 0.9161
# MAE               : 0.7747
# R^2 (Coefficient) : 0.1604
# Explained Variance: 0.1605
