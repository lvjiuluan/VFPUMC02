# %%
import sys
import os
sys.path.append('D:\PyCharmProjects\VFPUMC02')
sys.path.append(r'C:\Users\Administrator\PycharmProjects\VFPUMC02')
sys.path.append(r'/root/VFPUMC02')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from classfiers.VF_SBT import VF_SBT
from consts.Constants import DATASETS_PATH
from utils.FateUtils import load_host_guest_data

# %%
XA, XB, y = load_host_guest_data(os.path.join(DATASETS_PATH,'breast_hetero_host.csv'),
                                 os.path.join(DATASETS_PATH,'breast_hetero_guest.csv'),
                                 skip_columns=['sample_id', 'id'])
# Out:
# 成功读取 /root/VFPUMC02/datasets/breast_hetero_host.csv 和 /root/VFPUMC02/datasets/breast_hetero_guest.csv
# A_host.csv 中跳过的列: {'id'}
# B_guest.csv 中跳过的列: {'id'}

# %%
config = {
    'num_trees':4,
    'learning_rate': 0.2
}
vf_sbt = VF_SBT(config)
# Out:
# 配置已成功保存到 /root/VFPUMC02/configs/sbtConfig.yaml

# %%
SBT_SCRIPT_PATH
# Out:
# '/root/VFPUMC02/scripts/sbt.py'

# %%
vf_sbt.fit(XA,XB,y)
# Out:
# DataFrame 已成功保存到 /root/VFPUMC02/datasets/A_host.csv
# DataFrame 已成功保存到 /root/VFPUMC02/datasets/B_guest.csv
# 两个 DataFrame 已成功保存到：
#   /root/VFPUMC02/datasets/A_host.csv
#   /root/VFPUMC02/datasets/B_guest.csv
# Standard Output: [01:12:49] ERROR    [Rank:0] exception in rank 0:   ]8;id=114273;file:///root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/arch/launchers/multiprocess_launcher.py\multiprocess_launcher.py]8;;\:]8;id=490514;file:///root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/arch/launchers/multiprocess_launcher.py#164\164]8;;\
#                     '<' not supported between
#                     instances of 'Tensor' and 'str'
#                     Stack (most recent call last):
#                       File "<string>", line 1, in
#                     <module>
#                       File
#                     "/root/miniconda3/envs/fate_env
#                     2/lib/python3.10/multiprocessin
#                     g/spawn.py", line 116, in
#                     spawn_main
#                         exitcode = _main(fd,
#                     parent_sentinel)
#                       File
#                     "/root/miniconda3/envs/fate_env
#                     2/lib/python3.10/multiprocessin
#                     g/spawn.py", line 129, in _main
#                         return
#                     self._bootstrap(parent_sentinel
#                     )
#                       File
#                     "/root/miniconda3/envs/fate_env
#                     2/lib/python3.10/multiprocessin
#                     g/process.py", line 314, in
#                     _bootstrap
#                         self.run()
#                       File
#                     "/root/miniconda3/envs/fate_env
#                     2/lib/python3.10/multiprocessin
#                     g/process.py", line 108, in run
#                         self._target(*self._args,
#                     **self._kwargs)
#                       File
#                     "/root/miniconda3/envs/fate_env
#                     2/lib/python3.10/site-packages/
#                     fate/arch/launchers/multiproces
#                     s_launcher.py", line 164, in
#                     _run_process
#                         logger.error(f"exception in
#                     rank {args.rank}: {e}",
#                     stack_info=True)
# ╭────────────────────────────── rank 0 exception ──────────────────────────────╮
# │ ╭─────────────────── Traceback (most recent call last) ────────────────────╮ │
# │ │ /root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/arch/l │ │
# │ │ aunchers/multiprocess_launcher.py:156 in _run_process                    │ │
# │ │                                                                          │ │
# │ │   153 │   │   │                                                          │ │
# │ │   154 │   │   │   try:                                                   │ │
# │ │   155 │   │   │   │   profile_start()                                    │ │
# │ │ ❱ 156 │   │   │   │   f(ctx)                                             │ │
# │ │   157 │   │   │   │   profile_ends()                                     │ │
# │ │   158 │   │   │   │   output_or_exception_q.put((args.rank, None, None)) │ │
# │ │   159 │   │   │   │   safe_to_exit.wait()                                │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │                  args = LauncherProcessArguments(                    │ │ │
# │ │ │                         │   log_level='ERROR',                       │ │ │
# │ │ │                         │   rank=0,                                  │ │ │
# │ │ │                         │   parties=['guest:9999', 'host:10000']     │ │ │
# │ │ │                         )                                            │ │ │
# │ │ │                  argv = [                                            │ │ │
# │ │ │                         │   '/root/VFPUMC02/scripts/sbt.py',         │ │ │
# │ │ │                         │   '--parties',                             │ │ │
# │ │ │                         │   'guest:9999',                            │ │ │
# │ │ │                         │   'host:10000',                            │ │ │
# │ │ │                         │   '--log_level',                           │ │ │
# │ │ │                         │   'ERROR',                                 │ │ │
# │ │ │                         │   '--rank',                                │ │ │
# │ │ │                         │   '0'                                      │ │ │
# │ │ │                         ]                                            │ │ │
# │ │ │               carrier = {}                                           │ │ │
# │ │ │                   cls = <class                                       │ │ │
# │ │ │                         'fate.arch.launchers.multiprocess_launcher.… │ │ │
# │ │ │           csession_id = '20250113011239-6cff20_guest_9999'           │ │ │
# │ │ │                   ctx = <fate.arch.context._context.Context object   │ │ │
# │ │ │                         at 0x7feb08e98b20>                           │ │ │
# │ │ │                     e = TypeError("'<' not supported between         │ │ │
# │ │ │                         instances of 'Tensor' and 'str'")            │ │ │
# │ │ │                     f = <function run at 0x7feb08ff1870>             │ │ │
# │ │ │ federation_session_id = '20250113011239-6cff20'                      │ │ │
# │ │ │          init_context = <function init_context at 0x7feb08e35240>    │ │ │
# │ │ │                logger = <Logger                                      │ │ │
# │ │ │                         fate.arch.launchers.multiprocess_launcher    │ │ │
# │ │ │                         (ERROR)>                                     │ │ │
# │ │ │ output_or_exception_q = <multiprocessing.queues.Queue object at      │ │ │
# │ │ │                         0x7fec16da6a40>                              │ │ │
# │ │ │               parties = [('guest', '9999'), ('host', '10000')]       │ │ │
# │ │ │                 party = ('guest', '9999')                            │ │ │
# │ │ │          profile_ends = <function profile_ends at 0x7febc2a844c0>    │ │ │
# │ │ │         profile_start = <function profile_start at 0x7febc2a84430>   │ │ │
# │ │ │          safe_to_exit = <multiprocessing.synchronize.Event object at │ │ │
# │ │ │                         0x7feb08fb15a0>                              │ │ │
# │ │ │        set_up_logging = <function set_up_logging at 0x7feb08ff2440>  │ │ │
# │ │ │         setup_tracing = <function setup_tracing at 0x7febc2a7ecb0>   │ │ │
# │ │ │                  span = NonRecordingSpan(SpanContext(trace_id=0x000… │ │ │
# │ │ │                         span_id=0x0000000000000000,                  │ │ │
# │ │ │                         trace_flags=0x00, trace_state=[],            │ │ │
# │ │ │                         is_remote=False))                            │ │ │
# │ │ │                tracer = <opentelemetry.trace.NoOpTracer object at    │ │ │
# │ │ │                         0x7feb08e101c0>                              │ │ │
# │ │ │                 width = 80                                           │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/VFPUMC02/scripts/sbt.py:68 in run                                  │ │
# │ │                                                                          │ │
# │ │   65 │   if ctx.is_on_guest:                                             │ │
# │ │   66 │   │   guest_result = {}                                           │ │
# │ │   67 │   │   data = csv_to_df(ctx, B_guest_path)                         │ │
# │ │ ❱ 68 │   │   bst = train(ctx, data, config)                              │ │
# │ │   69 │   │   model_dict = bst.get_model()                                │ │
# │ │   70 │   │   pred = predict(ctx, data, model_dict)                       │ │
# │ │   71 │   │   pred_df = pred.as_pd_df()                                   │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │       config = {                                                     │ │ │
# │ │ │                │   'num_trees': 4,                                   │ │ │
# │ │ │                │   'max_depth': 3,                                   │ │ │
# │ │ │                │   'complete_secure': 0,                             │ │ │
# │ │ │                │   'learning_rate': 0.2,                             │ │ │
# │ │ │                │   'objective': 'binary:bce',                        │ │ │
# │ │ │                │   'num_class': 1,                                   │ │ │
# │ │ │                │   'max_bin': 32,                                    │ │ │
# │ │ │                │   'l2': 0.1,                                        │ │ │
# │ │ │                │   'l1': 0,                                          │ │ │
# │ │ │                │   'min_impurity_split': '1e-2',                     │ │ │
# │ │ │                │   ... +12                                           │ │ │
# │ │ │                }                                                     │ │ │
# │ │ │          ctx = <fate.arch.context._context.Context object at         │ │ │
# │ │ │                0x7feb08e98b20>                                       │ │ │
# │ │ │         data = <fate.arch.dataframe._dataframe.DataFrame object at   │ │ │
# │ │ │                0x7feb08fb1ab0>                                       │ │ │
# │ │ │ guest_result = {}                                                    │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/VFPUMC02/scripts/sbt.py:38 in train                                │ │
# │ │                                                                          │ │
# │ │   35 │   │   filtered_config = filter_params_for_class(HeteroSecureBoost │ │
# │ │   36 │   │   bst = HeteroSecureBoostHost(**filtered_config)              │ │
# │ │   37 │                                                                   │ │
# │ │ ❱ 38 │   bst.fit(ctx, data)                                              │ │
# │ │   39 │                                                                   │ │
# │ │   40 │   return bst                                                      │ │
# │ │   41                                                                     │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │             bst = <fate.ml.ensemble.algo.secureboost.hetero.guest.H… │ │ │
# │ │ │                   object at 0x7feb08fb1b70>                          │ │ │
# │ │ │          config = {                                                  │ │ │
# │ │ │                   │   'num_trees': 4,                                │ │ │
# │ │ │                   │   'max_depth': 3,                                │ │ │
# │ │ │                   │   'complete_secure': 0,                          │ │ │
# │ │ │                   │   'learning_rate': 0.2,                          │ │ │
# │ │ │                   │   'objective': 'binary:bce',                     │ │ │
# │ │ │                   │   'num_class': 1,                                │ │ │
# │ │ │                   │   'max_bin': 32,                                 │ │ │
# │ │ │                   │   'l2': 0.1,                                     │ │ │
# │ │ │                   │   'l1': 0,                                       │ │ │
# │ │ │                   │   'min_impurity_split': '1e-2',                  │ │ │
# │ │ │                   │   ... +12                                        │ │ │
# │ │ │                   }                                                  │ │ │
# │ │ │             ctx = <fate.arch.context._context.Context object at      │ │ │
# │ │ │                   0x7feb08e98b20>                                    │ │ │
# │ │ │            data = <fate.arch.dataframe._dataframe.DataFrame object   │ │ │
# │ │ │                   at 0x7feb08fb1ab0>                                 │ │ │
# │ │ │ filtered_config = {                                                  │ │ │
# │ │ │                   │   'num_trees': 4,                                │ │ │
# │ │ │                   │   'max_depth': 3,                                │ │ │
# │ │ │                   │   'complete_secure': 0,                          │ │ │
# │ │ │                   │   'learning_rate': 0.2,                          │ │ │
# │ │ │                   │   'objective': 'binary:bce',                     │ │ │
# │ │ │                   │   'num_class': 1,                                │ │ │
# │ │ │                   │   'max_bin': 32,                                 │ │ │
# │ │ │                   │   'l2': 0.1,                                     │ │ │
# │ │ │                   │   'l1': 0,                                       │ │ │
# │ │ │                   │   'min_impurity_split': '1e-2',                  │ │ │
# │ │ │                   │   ... +11                                        │ │ │
# │ │ │                   }                                                  │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ens │ │
# │ │ emble/algo/secureboost/hetero/guest.py:317 in fit                        │ │
# │ │                                                                          │ │
# │ │   314 │   │   │   │   │   │   target_gh = goss_sample(target_gh, self.to │ │
# │ │   315 │   │   │   │   │   │   logger.debug("goss sample done, got {} sam │ │
# │ │   316 │   │   │   │                                                      │ │
# │ │ ❱ 317 │   │   │   │   tree.booster_fit(tree_ctx_, bin_data, target_gh, b │ │
# │ │   318 │   │   │   │   # accumulate scores of cur boosting round          │ │
# │ │   319 │   │   │   │   scores = tree.get_sample_predict_weights()         │ │
# │ │   320 │   │   │   │   assert len(scores) == len(                         │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │      bin_data = <fate.arch.dataframe._dataframe.DataFrame object at  │ │ │
# │ │ │                 0x7feab172de70>                                      │ │ │
# │ │ │      bin_info = {                                                    │ │ │
# │ │ │                 │   'x0': [                                          │ │ │
# │ │ │                 │   │   -1.7269010543823242,                         │ │ │
# │ │ │                 │   │   -1.3054879903793335,                         │ │ │
# │ │ │                 │   │   -1.1429280042648315,                         │ │ │
# │ │ │                 │   │   -1.060094952583313,                          │ │ │
# │ │ │                 │   │   -0.9627659916877747,                         │ │ │
# │ │ │                 │   │   -0.8799329996109009,                         │ │ │
# │ │ │                 │   │   -0.807453989982605,                          │ │ │
# │ │ │                 │   │   -0.7266920208930969,                         │ │ │
# │ │ │                 │   │   -0.6749209761619568,                         │ │ │
# │ │ │                 │   │   -0.6438590288162231,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x1': [                                          │ │ │
# │ │ │                 │   │   -2.223994016647339,                          │ │ │
# │ │ │                 │   │   -1.605188012123108,                          │ │ │
# │ │ │                 │   │   -1.4260590076446533,                         │ │ │
# │ │ │                 │   │   -1.2990410327911377,                         │ │ │
# │ │ │                 │   │   -1.1948210000991821,                         │ │ │
# │ │ │                 │   │   -1.0433770418167114,                         │ │ │
# │ │ │                 │   │   -0.9668400287628174,                         │ │ │
# │ │ │                 │   │   -0.8447070121765137,                         │ │ │
# │ │ │                 │   │   -0.7518860101699829,                         │ │ │
# │ │ │                 │   │   -0.6476659774780273,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x2': [                                          │ │ │
# │ │ │                 │   │   -1.6933610439300537,                         │ │ │
# │ │ │                 │   │   -1.2882740497589111,                         │ │ │
# │ │ │                 │   │   -1.1453020572662354,                         │ │ │
# │ │ │                 │   │   -1.0598160028457642,                         │ │ │
# │ │ │                 │   │   -0.9552680253982544,                         │ │ │
# │ │ │                 │   │   -0.8694850206375122,                         │ │ │
# │ │ │                 │   │   -0.8140829801559448,                         │ │ │
# │ │ │                 │   │   -0.7327679991722107,                         │ │ │
# │ │ │                 │   │   -0.6904720067977905,                         │ │ │
# │ │ │                 │   │   -0.6591969728469849,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x3': [                                          │ │ │
# │ │ │                 │   │   -1.2224229574203491,                         │ │ │
# │ │ │                 │   │   -1.025712013244629,                          │ │ │
# │ │ │                 │   │   -0.9293789863586426,                         │ │ │
# │ │ │                 │   │   -0.8861340284347534,                         │ │ │
# │ │ │                 │   │   -0.826541006565094,                          │ │ │
# │ │ │                 │   │   -0.7731000185012817,                         │ │ │
# │ │ │                 │   │   -0.7201870083808899,                         │ │ │
# │ │ │                 │   │   -0.6869630217552185,                         │ │ │
# │ │ │                 │   │   -0.6444209814071655,                         │ │ │
# │ │ │                 │   │   -0.6201620101928711,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x4': [                                          │ │ │
# │ │ │                 │   │   -2.682694911956787,                          │ │ │
# │ │ │                 │   │   -1.7130450010299683,                         │ │ │
# │ │ │                 │   │   -1.4798380136489868,                         │ │ │
# │ │ │                 │   │   -1.3268510103225708,                         │ │ │
# │ │ │                 │   │   -1.1383559703826904,                         │ │ │
# │ │ │                 │   │   -1.0287669897079468,                         │ │ │
# │ │ │                 │   │   -0.9147930145263672,                         │ │ │
# │ │ │                 │   │   -0.8095870018005371,                         │ │ │
# │ │ │                 │   │   -0.6912299990653992,                         │ │ │
# │ │ │                 │   │   -0.577256977558136,                          │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x5': [                                          │ │ │
# │ │ │                 │   │   -1.4438780546188354,                         │ │ │
# │ │ │                 │   │   -1.2218660116195679,                         │ │ │
# │ │ │                 │   │   -1.1399940252304077,                         │ │ │
# │ │ │                 │   │   -1.0468000173568726,                         │ │ │
# │ │ │                 │   │   -0.9813410043716431,                         │ │ │
# │ │ │                 │   │   -0.9145470261573792,                         │ │ │
# │ │ │                 │   │   -0.8337569832801819,                         │ │ │
# │ │ │                 │   │   -0.757420003414154,                          │ │ │
# │ │ │                 │   │   -0.6887170076370239,                         │ │ │
# │ │ │                 │   │   -0.6365529894828796,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x6': [                                          │ │ │
# │ │ │                 │   │   -1.305830955505371,                          │ │ │
# │ │ │                 │   │   -1.2793580293655396,                         │ │ │
# │ │ │                 │   │   -1.1985100507736206,                         │ │ │
# │ │ │                 │   │   -1.1083650588989258,                         │ │ │
# │ │ │                 │   │   -1.0112149715423584,                         │ │ │
# │ │ │                 │   │   -0.9608889818191528,                         │ │ │
# │ │ │                 │   │   -0.892524003982544,                          │ │ │
# │ │ │                 │   │   -0.8262699842453003,                         │ │ │
# │ │ │                 │   │   -0.7569940090179443,                         │ │ │
# │ │ │                 │   │   -0.6941459774971008,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x7': [                                          │ │ │
# │ │ │                 │   │   -1.7450629472732544,                         │ │ │
# │ │ │                 │   │   -1.5758949518203735,                         │ │ │
# │ │ │                 │   │   -1.352368950843811,                          │ │ │
# │ │ │                 │   │   -1.201321005821228,                          │ │ │
# │ │ │                 │   │   -1.0721989870071411,                         │ │ │
# │ │ │                 │   │   -0.9758149981498718,                         │ │ │
# │ │ │                 │   │   -0.8922209739685059,                         │ │ │
# │ │ │                 │   │   -0.8250719904899597,                         │ │ │
# │ │ │                 │   │   -0.768580973148346,                          │ │ │
# │ │ │                 │   │   -0.7028020024299622,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x8': [                                          │ │ │
# │ │ │                 │   │   -2.1609599590301514,                         │ │ │
# │ │ │                 │   │   -1.4928159713745117,                         │ │ │
# │ │ │                 │   │   -1.1902910470962524,                         │ │ │
# │ │ │                 │   │   -1.0543979406356812,                         │ │ │
# │ │ │                 │   │   -0.9718909859657288,                         │ │ │
# │ │ │                 │   │   -0.8812950253486633,                         │ │ │
# │ │ │                 │   │   -0.8036419749259949,                         │ │ │
# │ │ │                 │   │   -0.72598797082901,                           │ │ │
# │ │ │                 │   │   -0.6450989842414856,                         │ │ │
# │ │ │                 │   │   -0.583624005317688,                          │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ],                                               │ │ │
# │ │ │                 │   'x9': [                                          │ │ │
# │ │ │                 │   │   -1.6018389463424683,                         │ │ │
# │ │ │                 │   │   -1.2870780229568481,                         │ │ │
# │ │ │                 │   │   -1.1490919589996338,                         │ │ │
# │ │ │                 │   │   -1.0271769762039185,                         │ │ │
# │ │ │                 │   │   -0.9457160234451294,                         │ │ │
# │ │ │                 │   │   -0.8869749903678894,                         │ │ │
# │ │ │                 │   │   -0.8160430192947388,                         │ │ │
# │ │ │                 │   │   -0.7528690099716187,                         │ │ │
# │ │ │                 │   │   -0.7024409770965576,                         │ │ │
# │ │ │                 │   │   -0.6326169967651367,                         │ │ │
# │ │ │                 │   │   ... +22                                      │ │ │
# │ │ │                 │   ]                                                │ │ │
# │ │ │                 }                                                    │ │ │
# │ │ │           ctx = <fate.arch.context._context.Context object at        │ │ │
# │ │ │                 0x7feb08e98b20>                                      │ │ │
# │ │ │            gh = <fate.arch.dataframe._dataframe.DataFrame object at  │ │ │
# │ │ │                 0x7feab17460e0>                                      │ │ │
# │ │ │      iter_dix = 0                                                    │ │ │
# │ │ │         label = <fate.arch.dataframe._dataframe.DataFrame object at  │ │ │
# │ │ │                 0x7feab172c2b0>                                      │ │ │
# │ │ │          self = <fate.ml.ensemble.algo.secureboost.hetero.guest.Het… │ │ │
# │ │ │                 object at 0x7feb08fb1b70>                            │ │ │
# │ │ │     target_gh = <fate.arch.dataframe._dataframe.DataFrame object at  │ │ │
# │ │ │                 0x7feab17460e0>                                      │ │ │
# │ │ │    train_data = <fate.arch.dataframe._dataframe.DataFrame object at  │ │ │
# │ │ │                 0x7feb08fb1ab0>                                      │ │ │
# │ │ │          tree = <fate.ml.ensemble.learner.decision_tree.hetero.gues… │ │ │
# │ │ │                 object at 0x7feab1746770>                            │ │ │
# │ │ │      tree_ctx = <fate.arch.context._context.Context object at        │ │ │
# │ │ │                 0x7feab172db70>                                      │ │ │
# │ │ │     tree_ctx_ = <fate.arch.context._context.Context object at        │ │ │
# │ │ │                 0x7feab1745690>                                      │ │ │
# │ │ │      tree_dim = 0                                                    │ │ │
# │ │ │     tree_mode = 'all'                                                │ │ │
# │ │ │ validate_data = None                                                 │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ens │ │
# │ │ emble/learner/decision_tree/hetero/guest.py:363 in booster_fit           │ │
# │ │                                                                          │ │
# │ │   360 │   │   │   )                                                      │ │
# │ │   361 │   │   │   # compute best splits                                  │ │
# │ │   362 │   │   │   use_local_feat_only = True if self._tree_mode == GUEST │ │
# │ │ ❱ 363 │   │   │   split_info = self.splitter.split(                      │ │
# │ │   364 │   │   │   │   sub_ctx,                                           │ │
# │ │   365 │   │   │   │   statistic_result,                                  │ │
# │ │   366 │   │   │   │   cur_layer_node,                                    │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │      bin_train_data = <fate.arch.dataframe._dataframe.DataFrame      │ │ │
# │ │ │                       object at 0x7feab172de70>                      │ │ │
# │ │ │        binning_dict = {                                              │ │ │
# │ │ │                       │   'x0': [                                    │ │ │
# │ │ │                       │   │   -1.7269010543823242,                   │ │ │
# │ │ │                       │   │   -1.3054879903793335,                   │ │ │
# │ │ │                       │   │   -1.1429280042648315,                   │ │ │
# │ │ │                       │   │   -1.060094952583313,                    │ │ │
# │ │ │                       │   │   -0.9627659916877747,                   │ │ │
# │ │ │                       │   │   -0.8799329996109009,                   │ │ │
# │ │ │                       │   │   -0.807453989982605,                    │ │ │
# │ │ │                       │   │   -0.7266920208930969,                   │ │ │
# │ │ │                       │   │   -0.6749209761619568,                   │ │ │
# │ │ │                       │   │   -0.6438590288162231,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x1': [                                    │ │ │
# │ │ │                       │   │   -2.223994016647339,                    │ │ │
# │ │ │                       │   │   -1.605188012123108,                    │ │ │
# │ │ │                       │   │   -1.4260590076446533,                   │ │ │
# │ │ │                       │   │   -1.2990410327911377,                   │ │ │
# │ │ │                       │   │   -1.1948210000991821,                   │ │ │
# │ │ │                       │   │   -1.0433770418167114,                   │ │ │
# │ │ │                       │   │   -0.9668400287628174,                   │ │ │
# │ │ │                       │   │   -0.8447070121765137,                   │ │ │
# │ │ │                       │   │   -0.7518860101699829,                   │ │ │
# │ │ │                       │   │   -0.6476659774780273,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x2': [                                    │ │ │
# │ │ │                       │   │   -1.6933610439300537,                   │ │ │
# │ │ │                       │   │   -1.2882740497589111,                   │ │ │
# │ │ │                       │   │   -1.1453020572662354,                   │ │ │
# │ │ │                       │   │   -1.0598160028457642,                   │ │ │
# │ │ │                       │   │   -0.9552680253982544,                   │ │ │
# │ │ │                       │   │   -0.8694850206375122,                   │ │ │
# │ │ │                       │   │   -0.8140829801559448,                   │ │ │
# │ │ │                       │   │   -0.7327679991722107,                   │ │ │
# │ │ │                       │   │   -0.6904720067977905,                   │ │ │
# │ │ │                       │   │   -0.6591969728469849,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x3': [                                    │ │ │
# │ │ │                       │   │   -1.2224229574203491,                   │ │ │
# │ │ │                       │   │   -1.025712013244629,                    │ │ │
# │ │ │                       │   │   -0.9293789863586426,                   │ │ │
# │ │ │                       │   │   -0.8861340284347534,                   │ │ │
# │ │ │                       │   │   -0.826541006565094,                    │ │ │
# │ │ │                       │   │   -0.7731000185012817,                   │ │ │
# │ │ │                       │   │   -0.7201870083808899,                   │ │ │
# │ │ │                       │   │   -0.6869630217552185,                   │ │ │
# │ │ │                       │   │   -0.6444209814071655,                   │ │ │
# │ │ │                       │   │   -0.6201620101928711,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x4': [                                    │ │ │
# │ │ │                       │   │   -2.682694911956787,                    │ │ │
# │ │ │                       │   │   -1.7130450010299683,                   │ │ │
# │ │ │                       │   │   -1.4798380136489868,                   │ │ │
# │ │ │                       │   │   -1.3268510103225708,                   │ │ │
# │ │ │                       │   │   -1.1383559703826904,                   │ │ │
# │ │ │                       │   │   -1.0287669897079468,                   │ │ │
# │ │ │                       │   │   -0.9147930145263672,                   │ │ │
# │ │ │                       │   │   -0.8095870018005371,                   │ │ │
# │ │ │                       │   │   -0.6912299990653992,                   │ │ │
# │ │ │                       │   │   -0.577256977558136,                    │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x5': [                                    │ │ │
# │ │ │                       │   │   -1.4438780546188354,                   │ │ │
# │ │ │                       │   │   -1.2218660116195679,                   │ │ │
# │ │ │                       │   │   -1.1399940252304077,                   │ │ │
# │ │ │                       │   │   -1.0468000173568726,                   │ │ │
# │ │ │                       │   │   -0.9813410043716431,                   │ │ │
# │ │ │                       │   │   -0.9145470261573792,                   │ │ │
# │ │ │                       │   │   -0.8337569832801819,                   │ │ │
# │ │ │                       │   │   -0.757420003414154,                    │ │ │
# │ │ │                       │   │   -0.6887170076370239,                   │ │ │
# │ │ │                       │   │   -0.6365529894828796,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x6': [                                    │ │ │
# │ │ │                       │   │   -1.305830955505371,                    │ │ │
# │ │ │                       │   │   -1.2793580293655396,                   │ │ │
# │ │ │                       │   │   -1.1985100507736206,                   │ │ │
# │ │ │                       │   │   -1.1083650588989258,                   │ │ │
# │ │ │                       │   │   -1.0112149715423584,                   │ │ │
# │ │ │                       │   │   -0.9608889818191528,                   │ │ │
# │ │ │                       │   │   -0.892524003982544,                    │ │ │
# │ │ │                       │   │   -0.8262699842453003,                   │ │ │
# │ │ │                       │   │   -0.7569940090179443,                   │ │ │
# │ │ │                       │   │   -0.6941459774971008,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x7': [                                    │ │ │
# │ │ │                       │   │   -1.7450629472732544,                   │ │ │
# │ │ │                       │   │   -1.5758949518203735,                   │ │ │
# │ │ │                       │   │   -1.352368950843811,                    │ │ │
# │ │ │                       │   │   -1.201321005821228,                    │ │ │
# │ │ │                       │   │   -1.0721989870071411,                   │ │ │
# │ │ │                       │   │   -0.9758149981498718,                   │ │ │
# │ │ │                       │   │   -0.8922209739685059,                   │ │ │
# │ │ │                       │   │   -0.8250719904899597,                   │ │ │
# │ │ │                       │   │   -0.768580973148346,                    │ │ │
# │ │ │                       │   │   -0.7028020024299622,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x8': [                                    │ │ │
# │ │ │                       │   │   -2.1609599590301514,                   │ │ │
# │ │ │                       │   │   -1.4928159713745117,                   │ │ │
# │ │ │                       │   │   -1.1902910470962524,                   │ │ │
# │ │ │                       │   │   -1.0543979406356812,                   │ │ │
# │ │ │                       │   │   -0.9718909859657288,                   │ │ │
# │ │ │                       │   │   -0.8812950253486633,                   │ │ │
# │ │ │                       │   │   -0.8036419749259949,                   │ │ │
# │ │ │                       │   │   -0.72598797082901,                     │ │ │
# │ │ │                       │   │   -0.6450989842414856,                   │ │ │
# │ │ │                       │   │   -0.583624005317688,                    │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ],                                         │ │ │
# │ │ │                       │   'x9': [                                    │ │ │
# │ │ │                       │   │   -1.6018389463424683,                   │ │ │
# │ │ │                       │   │   -1.2870780229568481,                   │ │ │
# │ │ │                       │   │   -1.1490919589996338,                   │ │ │
# │ │ │                       │   │   -1.0271769762039185,                   │ │ │
# │ │ │                       │   │   -0.9457160234451294,                   │ │ │
# │ │ │                       │   │   -0.8869749903678894,                   │ │ │
# │ │ │                       │   │   -0.8160430192947388,                   │ │ │
# │ │ │                       │   │   -0.7528690099716187,                   │ │ │
# │ │ │                       │   │   -0.7024409770965576,                   │ │ │
# │ │ │                       │   │   -0.6326169967651367,                   │ │ │
# │ │ │                       │   │   ... +22                                │ │ │
# │ │ │                       │   ]                                          │ │ │
# │ │ │                       }                                              │ │ │
# │ │ │                 ctx = <fate.arch.context._context.Context object at  │ │ │
# │ │ │                       0x7feab1745690>                                │ │ │
# │ │ │           cur_depth = 0                                              │ │ │
# │ │ │      cur_layer_node = [                                              │ │ │
# │ │ │                       │   (node_id 0: fid None bid None left -1,     │ │ │
# │ │ │                       right -1, pid None, is_leaf False,             │ │ │
# │ │ │                       sample_count 569,  g -72.5, h 142.25, weight   │ │ │
# │ │ │                       0.0, sitename guest_9999)                      │ │ │
# │ │ │                       ]                                              │ │ │
# │ │ │       grad_and_hess = <fate.arch.dataframe._dataframe.DataFrame      │ │ │
# │ │ │                       object at 0x7feab17460e0>                      │ │ │
# │ │ │           hist_inst = <fate.arch.histogram._histogram_sbt.Histogram… │ │ │
# │ │ │                       object at 0x7fe83010c7c0>                      │ │ │
# │ │ │            node_map = {0: 0}                                         │ │ │
# │ │ │           root_node = (node_id 0: fid None bid None left -1, right   │ │ │
# │ │ │                       -1, pid None, is_leaf False, sample_count 569, │ │ │
# │ │ │                       g -72.5, h 142.25, weight 0.0, sitename        │ │ │
# │ │ │                       guest_9999)                                    │ │ │
# │ │ │          sample_pos = <fate.arch.dataframe._dataframe.DataFrame      │ │ │
# │ │ │                       object at 0x7feab1747280>                      │ │ │
# │ │ │                self = <fate.ml.ensemble.learner.decision_tree.heter… │ │ │
# │ │ │                       object at 0x7feab1746770>                      │ │ │
# │ │ │      send_pack_info = {                                              │ │ │
# │ │ │                       │   'total_pack_num': 8,                       │ │ │
# │ │ │                       │   'split_point_shift_bit': 126,              │ │ │
# │ │ │                       │   'split_info_pack': True                    │ │ │
# │ │ │                       }                                              │ │ │
# │ │ │    statistic_result = <fate.arch.histogram._histogram_distributed.D… │ │ │
# │ │ │                       object at 0x7fe83010ec80>                      │ │ │
# │ │ │             sub_ctx = <fate.arch.context._context.Context object at  │ │ │
# │ │ │                       0x7feab1747070>                                │ │ │
# │ │ │            train_df = <fate.arch.dataframe._dataframe.DataFrame      │ │ │
# │ │ │                       object at 0x7feab172de70>                      │ │ │
# │ │ │ use_local_feat_only = False                                          │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ens │ │
# │ │ emble/learner/decision_tree/tree_core/splitter.py:380 in split           │ │
# │ │                                                                          │ │
# │ │   377 │   │   │   │   ), "gh_pack should be bool, indicating if the gh i │ │
# │ │   378 │   │   │   │   if not gh_pack:                                    │ │
# │ │   379 │   │   │   │   │   logger.info("not using gh pack to split")      │ │
# │ │ ❱ 380 │   │   │   │   return self._guest_split(                          │ │
# │ │   381 │   │   │   │   │   ctx, histogram_statistic_result, cur_layer_nod │ │
# │ │   382 │   │   │   │   )                                                  │ │
# │ │   383 │   │   │   elif ctx.is_on_host:                                   │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │                      coder = <fate.arch.protocol.phe.paillier.Coder  │ │ │
# │ │ │                              object at 0x7feab172fa90>               │ │ │
# │ │ │                        ctx = <fate.arch.context._context.Context     │ │ │
# │ │ │                              object at 0x7feab1747070>               │ │ │
# │ │ │             cur_layer_node = [                                       │ │ │
# │ │ │                              │   (node_id 0: fid None bid None left  │ │ │
# │ │ │                              -1, right -1, pid None, is_leaf False,  │ │ │
# │ │ │                              sample_count 569,  g -72.5, h 142.25,   │ │ │
# │ │ │                              weight 0.0, sitename guest_9999)        │ │ │
# │ │ │                              ]                                       │ │ │
# │ │ │                    gh_pack = True                                    │ │ │
# │ │ │ histogram_statistic_result = <fate.arch.histogram._histogram_distri… │ │ │
# │ │ │                              object at 0x7fe83010ec80>               │ │ │
# │ │ │                local_split = False                                   │ │ │
# │ │ │                   node_map = {0: 0}                                  │ │ │
# │ │ │                  pack_info = {                                       │ │ │
# │ │ │                              │   'g_offset': 1,                      │ │ │
# │ │ │                              │   'shift_bit': 63,                    │ │ │
# │ │ │                              │   'precision': 52,                    │ │ │
# │ │ │                              │   'pack_num': 2,                      │ │ │
# │ │ │                              │   'total_pack_num': 8,                │ │ │
# │ │ │                              │   'split_point_shift_bit': 126        │ │ │
# │ │ │                              }                                       │ │ │
# │ │ │                       self = <fate.ml.ensemble.learner.decision_tre… │ │ │
# │ │ │                              object at 0x7fe83010e710>               │ │ │
# │ │ │                         sk = <fate.arch.protocol.phe.paillier.SK     │ │ │
# │ │ │                              object at 0x7feab172e170>               │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ │                                                                          │ │
# │ │ /root/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ens │ │
# │ │ emble/learner/decision_tree/tree_core/splitter.py:310 in _guest_split    │ │
# │ │                                                                          │ │
# │ │   307 │   │   reverse_node_map = {v: k for k, v in node_map.items()}     │ │
# │ │   308 │   │                                                              │ │
# │ │   309 │   │   # find local best splits                                   │ │
# │ │ ❱ 310 │   │   guest_best_splits = self._find_best_splits(                │ │
# │ │   311 │   │   │   histogram, sitename, cur_layer_node, reverse_node_map, │ │
# │ │   312 │   │   )                                                          │ │
# │ │   313 │   │   # find best splits from host parties                       │ │
# │ │                                                                          │ │
# │ │ ╭─────────────────────────────── locals ───────────────────────────────╮ │ │
# │ │ │            coder = <fate.arch.protocol.phe.paillier.Coder object at  │ │ │
# │ │ │                    0x7feab172fa90>                                   │ │ │
# ...
# │ │ │                           │   │    4.1345e+01, 5.3971e+01,           │ │ │
# │ │ │                           6.8357e+01, 8.3909e+01, 1.0077e+02,        │ │ │
# │ │ │                           1.1509e+02,                                │ │ │
# │ │ │                           │   │    1.2963e+02, 1.5106e+02,           │ │ │
# │ │ │                           1.7465e+02, 1.9596e+02, 2.1306e+02,        │ │ │
# │ │ │                           2.3402e+02,                                │ │ │
# │ │ │                           │   │    2.6317e+02, 2.9624e+02,           │ │ │
# │ │ │                           3.2796e+02, 3.3009e+02, 3.4727e+02,        │ │ │
# │ │ │                           3.4911e+02,                                │ │ │
# │ │ │                           │   │    3.5098e+02, 3.1227e+02,           │ │ │
# │ │ │                           2.8697e+02, 2.4534e+02, 2.0701e+02,        │ │ │
# │ │ │                           1.6566e+02,                                │ │ │
# │ │ │                           │   │    1.2935e+02, 9.3514e+01,           │ │ │
# │ │ │                           6.0099e+01, 1.7673e-06, 1.2912e+00,        │ │ │
# │ │ │                           1.2133e+00,                                │ │ │
# │ │ │                           │   │    5.8705e+00, 1.1299e+01,           │ │ │
# │ │ │                           1.5194e+01, 1.6852e+01, 2.3297e+01,        │ │ │
# │ │ │                           2.8150e+01,                                │ │ │
# │ │ │                           │   │    3.1211e+01, 3.6840e+01,           │ │ │
# │ │ │                           3.5474e+01, 4.1794e+01, 4.4042e+01,        │ │ │
# │ │ │                           4.9039e+01,                                │ │ │
# │ │ │                           │   │    5.2143e+01, 5.5732e+01,           │ │ │
# │ │ │                           5.6366e+01, 5.4310e+01, 5.8333e+01,        │ │ │
# │ │ │                           5.7715e+01,                                │ │ │
# │ │ │                           │   │    6.6838e+01, 6.0114e+01,           │ │ │
# │ │ │                           6.2306e+01, 6.5376e+01, 6.8083e+01,        │ │ │
# │ │ │                           6.6911e+01,                                │ │ │
# │ │ │                           │   │    6.3366e+01, 7.0344e+01,           │ │ │
# │ │ │                           7.4053e+01, 7.2754e+01, 4.9942e+01,        │ │ │
# │ │ │                           1.7673e-06,                                │ │ │
# │ │ │                           │   │    1.2912e+00, 3.6628e-01,           │ │ │
# │ │ │                           1.0554e+00, 1.1090e+00, 3.4958e+00,        │ │ │
# │ │ │                           8.6836e+00,                                │ │ │
# │ │ │                           │   │    8.3513e+00, 1.3557e+01,           │ │ │
# │ │ │                           1.7904e+01, 2.2705e+01, 2.7373e+01,        │ │ │
# │ │ │                           2.9218e+01,                                │ │ │
# │ │ │                           │   │    2.4055e+01, 2.8049e+01,           │ │ │
# │ │ │                           3.5738e+01, 3.6731e+01, 3.2080e+01,        │ │ │
# │ │ │                           3.3568e+01,                                │ │ │
# │ │ │                           │   │    4.6144e+01, 4.3216e+01,           │ │ │
# │ │ │                           4.1545e+01, 4.3464e+01, 4.6365e+01,        │ │ │
# │ │ │                           5.1177e+01,                                │ │ │
# │ │ │                           │   │    4.7603e+01, 5.4329e+01,           │ │ │
# │ │ │                           5.3545e+01, 4.4221e+01, 3.1200e+01,        │ │ │
# │ │ │                           2.6084e+01,                                │ │ │
# │ │ │                           │   │    1.8704e+01, 1.7673e-06]],         │ │ │
# │ │ │                           dtype=torch.float64)                       │ │ │
# │ │ │                    self = <fate.ml.ensemble.learner.decision_tree.t… │ │ │
# │ │ │                           object at 0x7fe83010e710>                  │ │ │
# │ │ │            union_mask_0 = tensor([[False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False,  True, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False,  True,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False,  True, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False,  True, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False,  True,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False,  True, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False,  True,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False,  True, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False,  True, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False,         │ │ │
# │ │ │                           True]])                                    │ │ │
# │ │ │            union_mask_1 = tensor([[ True, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False,  True,  True, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False,  True,       │ │ │
# │ │ │                           True, False, False, False, False, False,   │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False,  True,  True, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False,  True,  True, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False,  True,  │ │ │
# │ │ │                           │   │     True, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False,  True, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False,  True,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False,  True,  True, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False,  True,  True, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False, False,  │ │ │
# │ │ │                           │   │    False, False, False, False,       │ │ │
# │ │ │                           False, False, False, False, False,         │ │ │
# │ │ │                           True]])                                    │ │ │
# │ │ ╰──────────────────────────────────────────────────────────────────────╯ │ │
# │ ╰──────────────────────────────────────────────────────────────────────────╯ │
# │ TypeError: '<' not supported between instances of 'Tensor' and 'str'         │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Standard Error: /root/miniconda3/envs/fate_env2/lib/python3.10/multiprocessing/resource_tracker.py:224: UserWarning: resource_tracker: There appear to be 5 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
#
# Command failed with return code: 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 vf_sbt.fit(XA,XB,y)
#
# File ~/VFPUMC02/classfiers/VF_SBT.py:43, in VF_SBT.fit(self, XA, XB, y)
#      41 else:
#      42     print("Command failed with return code:", result.returncode)
# ---> 43 result = load_from_pkl(SBT_PKL_PATH)
#      44 self.result = result
#      45 print("VF_SBT训练结束")
#
# File ~/VFPUMC02/utils/pklUtils.py:44, in load_from_pkl(pkl_path)
#      29 """
#      30 从指定的 Pickle 文件加载并返回对象。
#      31
#    (...)
#      41 {'key': 'value'}
#      42 """
#      43 if not os.path.exists(pkl_path):
# ---> 44     raise FileNotFoundError(f"指定的文件 {pkl_path} 不存在。")
#      46 try:
#      47     with open(pkl_path, 'rb') as f:
#
# FileNotFoundError: 指定的文件 /root/VFPUMC02/datasets/sbt_result.pkl 不存在。
