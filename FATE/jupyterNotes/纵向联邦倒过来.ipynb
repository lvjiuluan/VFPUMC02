# %%
import sys
import os
sys.path.append('D:\PyCharmProjects\VFPUMC02')
sys.path.append(r'C:\Users\Administrator\PycharmProjects\VFPUMC02')
sys.path.append(r'/root/VFPUMC02')
DATA_BASE_PATH = r'/root/VFPUMC02/datasets'
A_host_path = os.path.join(DATA_BASE_PATH,'breast_hetero_host.csv')
B_guest_path = os.path.join(DATA_BASE_PATH,'breast_hetero_guest.csv')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from fate.arch.dataframe import PandasReader
import pandas as pd
from utils.FateUtils import *
from fate.ml.ensemble.algo.secureboost.hetero.guest import HeteroSecureBoostGuest
from fate.ml.ensemble.algo.secureboost.hetero.host import HeteroSecureBoostHost

# %%
A_df = pd.read_csv(A_host_path)
A_df['sample_id'] = [i for i in range(len(A_df))]

B_df = pd.read_csv(B_guest_path)
B_df['sample_id'] = [i for i in range(len(B_df))]

# %%
A_df.head()
# Out:
#     id        x0        x1        x2        x3        x4        x5        x6  \
# 0  133  0.449512 -1.247226  0.413178  0.303781 -0.123848 -0.184227 -0.219076
# 1  273 -1.245485 -0.842317 -1.255026 -1.038066 -0.426301 -1.088781 -0.976392
# 2  175 -1.549664 -1.126219 -1.546652 -1.216392 -0.354424 -1.167051 -1.114873
# 3  551 -0.851273  0.733108 -0.843535 -0.786363 -0.049836 -0.424532 -0.509221
# 4  199  0.091654  0.216499  0.103839 -0.034667  0.167930  0.308132  0.366614
#
#          x7        x8  ...       x11       x12       x13       x14       x15  \
# 0  0.268537  0.015996  ... -0.728193 -0.442587 -0.272757 -0.608018 -0.577235
# 1 -0.898898  0.983496  ...  0.348620 -0.552483 -0.526877  2.253098 -0.827620
# 2 -1.261820 -0.327193  ... -0.779358 -0.708418 -0.637545  0.710369 -0.976454
# 3 -0.679649  0.797298  ...  0.453852 -0.431696 -0.494754 -1.182041  0.281228
# 4  0.280661  0.505223  ... -1.026834 -0.702973 -0.460212 -0.999033 -0.531406
#
# ...

# %%
B_df.head()
# Out:
#     id  y        x0        x1        x2        x3        x4        x5  \
# 0  133  1  0.254879 -1.046633  0.209656  0.074214 -0.441366 -0.377645
# 1  273  1 -1.142928 -0.781198 -1.166747 -0.923578  0.628230 -1.021418
# 2  175  1 -1.451067 -1.406518 -1.456564 -1.092337 -0.708765 -1.168557
# 3  551  1 -0.879933  0.420589 -0.877527 -0.780484 -1.037534 -0.483880
# 4  199  0  0.426758  0.723479  0.316885  0.287273  1.000835  0.962702
#
#          x6        x7        x8        x9  sample_id
# 0 -0.485934  0.347072 -0.287570 -0.733474          0
# 1 -1.111867 -0.959523 -0.096672 -0.121683          1
# 2 -1.305831 -1.745063 -0.499499 -0.302893          2
# 3 -0.555498 -0.768581  0.433960 -0.200928          3
# 4  1.077099  1.053586  2.996525  0.961696          4

# %%
A_reader = PandasReader(sample_id_name='sample_id', match_id_name='id',dtype='float32')

# %%
B_reader = PandasReader(sample_id_name='sample_id', match_id_name='id',label_name='y',dtype='float32')

# %%
A_host_ctx, B_guest_ctx = create_host_guest_ctx()

# %%
A_data = A_reader.to_frame(A_host_ctx, A_df)
# Out:
# Process ForkProcess-9:
# Process ForkProcess-109:
# Process ForkProcess-121:
# Process ForkProcess-106:
# Process ForkProcess-30:
# Process ForkProcess-95:
# Process ForkProcess-120:
# Process ForkProcess-54:
# Process ForkProcess-93:
# Process ForkProcess-3:
# Process ForkProcess-68:
# Process ForkProcess-77:
# Process ForkProcess-118:
# Process ForkProcess-115:
# Process ForkProcess-107:
# Process ForkProcess-123:
# Process ForkProcess-80:
# Process ForkProcess-90:
# Process ForkProcess-67:
# Process ForkProcess-87:
# Process ForkProcess-65:
# Process ForkProcess-51:
# Process ForkProcess-38:
# Process ForkProcess-103:
# Process ForkProcess-119:
# Process ForkProcess-24:
# Process ForkProcess-108:
# Process ForkProcess-116:
# Process ForkProcess-100:
# Process ForkProcess-74:
# Process ForkProcess-94:
# Process ForkProcess-66:
# Process ForkProcess-25:
# Process ForkProcess-92:
# Process ForkProcess-122:
# Process ForkProcess-52:
# Process ForkProcess-60:
# Process ForkProcess-59:
# ...

# %%
B_data = B_reader.to_frame(B_guest_ctx, B_df)
# Out:
# Process ForkProcess-239:
# Process ForkProcess-219:
# Process ForkProcess-236:
# Process ForkProcess-227:
# Process ForkProcess-245:
# Process ForkProcess-240:
# Process ForkProcess-225:
# Process ForkProcess-215:
# Process ForkProcess-243:
# Process ForkProcess-206:
# Process ForkProcess-173:
# Process ForkProcess-221:
# Process ForkProcess-175:
# Process ForkProcess-148:
# Process ForkProcess-228:
# Process ForkProcess-200:
# Process ForkProcess-182:
# Process ForkProcess-199:
# Process ForkProcess-150:
# Process ForkProcess-205:
# Process ForkProcess-193:
# Process ForkProcess-160:
# Process ForkProcess-223:
# Process ForkProcess-189:
# Process ForkProcess-171:
# Process ForkProcess-159:
# Process ForkProcess-142:
# Process ForkProcess-181:
# Process ForkProcess-158:
# Process ForkProcess-176:
# Process ForkProcess-166:
# Process ForkProcess-138:
# Process ForkProcess-146:
# Process ForkProcess-147:
# Process ForkProcess-151:
# Process ForkProcess-129:
# Process ForkProcess-153:
# ...

# %%
A_host_bst = HeteroSecureBoostHost(num_trees=3, max_depth=3)

# %%
B_guest_bst = HeteroSecureBoostGuest(num_trees=3, objective='binary:bce', max_depth=3, learning_rate=0.3)

# %%
A_host_bst.fit(A_host_ctx, A_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 A_host_bst.fit(A_host_ctx, A_data)
#
# File ~/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ensemble/algo/secureboost/hetero/host.py:67, in HeteroSecureBoostHost.fit(self, ctx, train_data, validate_data)
#      64 logger.info("data binning done")
#      66 # tree dimension
# ---> 67 self._set_tree_dim(ctx)
#      69 # predict to help guest to get the warmstart scores
#      70 if self._model_loaded:
#
# File ~/miniconda3/envs/fate_env2/lib/python3.10/site-packages/fate/ml/ensemble/algo/secureboost/hetero/host.py:56, in HeteroSecureBoostHost._set_tree_dim(self, ctx)
#      55 def _set_tree_dim(self, ctx: Context):
# ---> 56     self._tree_dim = ctx.guest.get("tree_dim")
#      57     logger.info("tree dimension is {}".format(self._tree_dim))
#
# ...

# %%
B_guest_bst.fit(B_guest_bst,B_data)
