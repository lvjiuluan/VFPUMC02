# %%
import sys
sys.path.append('D:\PyCharmProjects\VFPUMC02')
sys.path.append(r'C:\Users\Administrator\PycharmProjects\VFPUMC02')
sys.path.append(r'/root/VFPUMC02')
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.FateUtils import get_data_by_objective, evaluate_model
from enums.SbtObjective import SbtObjective
from classfiers.VF_LinearRegression import VF_LinearRegression

# %%
XA_train, XA_test, XB_train, XB_test, y_train, y_test = get_data_by_objective(SbtObjective.REGRESSION_L2)

# %%
config = {
    'batch_size': 32,
    'lr': 0.01,
    'lambda': 0.1,
    'n_iters':10
}

# %%
vf_linear = VF_LinearRegression(config)
# Out:
# 2025-01-21 19:09:10,765 - ConsoleLogger - INFO - VF_LinearRegression 模型初始化完成。
# 2025-01-21 19:09:10,766 - ConsoleLogger - INFO - 模型配置: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}

# %%
vf_linear.fit(XA_train,XB_train,y_train)
# Out:
# 2025-01-21 19:09:10,787 - ConsoleLogger - INFO - 开始构建A、B、C三个客户端...
# 2025-01-21 19:09:10,787 - ConsoleLogger - INFO - Client 初始化完成，config: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}
# 2025-01-21 19:09:10,788 - ConsoleLogger - INFO - ClientA 初始化完成，数据维度: 353 x 5，初始权重长度: 5
# 2025-01-21 19:09:10,788 - ConsoleLogger - INFO - Client 初始化完成，config: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}
# 2025-01-21 19:09:10,789 - ConsoleLogger - INFO - ClientB 初始化完成，数据维度: 353 x 5，初始权重长度: 5
# 2025-01-21 19:09:10,789 - ConsoleLogger - INFO - Client 初始化完成，config: {'batch_size': 32, 'lr': 0.01, 'lambda': 0.1, 'n_iters': 10}
# 2025-01-21 19:09:10,789 - ConsoleLogger - INFO - ClientC 初始化完成，A_data_shape=(353, 5), B_data_shape=(353, 5)
# 2025-01-21 19:09:10,790 - ConsoleLogger - INFO - 正在为客户端A建立连接...
# 2025-01-21 19:09:10,790 - ConsoleLogger - INFO - 已建立连接：当前 Client -> [B]
# 2025-01-21 19:09:10,790 - ConsoleLogger - INFO - 已建立连接：当前 Client -> [C]
# ...

# %%
y_pred = vf_linear.predict(XA_test, XB_test)
# Out:
# 2025-01-21 19:10:07,244 - ConsoleLogger - INFO - 开始进行预测。
# 2025-01-21 19:10:07,245 - ConsoleLogger - INFO - 预测完成。

# %%
evaluate_model(y_test,y_pred,task='regression')
# Out:
# ========== Regression Metrics ==========
# MSE               : 26546.3535
# RMSE              : 162.9305
# MAE               : 145.7813
# R^2 (Coefficient) : -4.0105
# Explained Variance: 0.0008
